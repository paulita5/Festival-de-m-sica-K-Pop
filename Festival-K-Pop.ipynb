# %% [markdown]
# # **DESAFÍO K-POP**

# %% [markdown]
# Paula Cabrera Garcia

# %% [markdown]
# El objetivo de este proyecto era crear un festival de verano de música K-Pop para que el género incremente su popularidad.
#
# Para ello hemos analizado las 4 bases de datos de las que disponíamos, además de enriquecer nuestro trabajo con información extra, y con ese análisis hemos seleccionado los 10 grupos que van a formar parte de nuestro festival.
#
# Vamos a empezar a explicar el análisis de nuestros datos.

# %% [markdown]
# Para empezar, vamos a importar las librerías necesarias para realizar el proyecto.

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# A continuación vamos a cargar las bases de datos poco a poco. Esto lo hacemos para trabajar las bases de datos individualmente en profundidad.

# %% [markdown]
# Primero importamos la base de datos kpop_idols, para conocer y analizar a los fans de música k-pop.

# %%
df1=pd.read_csv('/content/kpop_idols.csv')
df1
# Out:
#      Stage Name      Full Name Korean Name K. Stage Name Date of Birth  \
# 0           A.M  Seong Hyunwoo         성현우           에이엠    1996-12-31
# 1           Ace  Jang Wooyoung         장우영           에이스    1992-08-28
# 2          Aeji      Kwon Aeji         권애지            애지    1999-10-25
# 3          AhIn       Lee Ahin         이아인            아인    1999-09-27
# 4          Ahra        Go Ahra         고아라            아라    2001-02-21
# ...         ...            ...         ...           ...           ...
# 1305        Ziu    Park Heejun         박희준            지우    1997-06-16
# 1306         ZN      Bae Jinye         배진예            지엔    1994-06-09
# 1307        Zoa     Cho Hyewon         조혜원            조아    2005-05-31
# 1308       Zuho       Bae Juho         백주호            주호    1996-07-04
# 1309       Zuny      Kim Joomi         김주미            주니    1994-12-08
#
#              Group      Country Birthplace Other Group Gender
# 0        Limitless  South Korea        NaN         NaN      M
# 1              VAV  South Korea        NaN         NaN      M
# 2          Hashtag  South Korea      Daegu         NaN      F
# 3         MOMOLAND  South Korea      Wonju         NaN      F
# 4         Favorite  South Korea      Yeosu         NaN      F
# ...            ...          ...        ...         ...    ...
# 1305           VAV  South Korea        NaN         NaN      M
# 1306        LABOUM  South Korea    Bucheon       UNI.T      F
# 1307       Weeekly  South Korea        NaN         NaN      F
# 1308           SF9  South Korea        NaN         NaN      M
# 1309  Ladies' Code  South Korea    Gwangju         NaN      F
#
# [1310 rows x 10 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Stage Name     1310 non-null   object
#  1   Full Name      1304 non-null   object
#  2   Korean Name    1304 non-null   object
#  3   K. Stage Name  1309 non-null   object
#  4   Date of Birth  1310 non-null   object
#  5   Group          1219 non-null   object
#  6   Country        1310 non-null   object
#  7   Birthplace     689 non-null    object
#  8   Other Group    122 non-null    object
#  9   Gender         1310 non-null   object
# dtypes: object(10)
# memory usage: 102.5+ KB

# %% [markdown]
# Vemos que contamos con 1310 registros y 10 columnas.
#
# En algunas columnas contamos con nulos, pero de momento no los vamos a tratar, si no a explicar.
#
# Las columnas con las que vamos a trabajar van a ser:
# -  'Full Name' y 'Korean Name' que corresponden con los nombres de los fans-
# - 'Date of Birth' que es la fecha de nacimiento de los fans, a esta columna le cambiaremos el tipo de dato ya que es un object pero nosotros la queremos de tipo date.
# - 'Group' que es el grupo favorito de los fans.
# - 'Country' que es el país de nacimiento de los fans.
# - 'Other Group' que es el segundo grupo favorito de los fans. Esta columna tiene muchos nulos, pero no vamos a tenerlos en cuenta para nuestro análisis.
# - 'Gender' que es el género de los fans.

# %%
df1=df1.drop(['Stage Name','K. Stage Name','Birthplace'],axis=1)

# %% [markdown]
# Vamos a comprobar si hay algún dato repetido por error.

# %%
duplicated_names_df1 = df1[df1.duplicated(subset=['Full Name'], keep=False)]
duplicated_names_df1
# Out:
#           Full Name Korean Name Date of Birth     Group      Country  \
# 1     Jang Wooyoung         장우영    1992-08-28       VAV  South Korea
# 14     Lee Seoyoung         이서영    2000-10-17      GWSN  South Korea
# 28      Lee Minhyuk         이민혁    1990-12-14   Block B  South Korea
# 44        Choi Yuna         최윤아    1999-02-02     ELRIS  South Korea
# 58        Kim Jiwon         김지원    1995-12-21      iKON  South Korea
# ...             ...         ...           ...       ...          ...
# 1244   Jung Yoonhye         정윤혜    1990-04-14   Rainbow  South Korea
# 1245   Jung Yoonhye         정윤혜    2001-10-04  FANATICS  South Korea
# 1246            NaN         NaN    1998-07-21     Lusty  South Korea
# 1267     Park Subin         박수빈    1996-12-25     H.U.B  South Korea
# 1277      Choi Yuna         최유나    1997-10-04   Gfriend  South Korea
#
#           Other Group Gender
# 1                 NaN      M
# 14                NaN      F
# 28            Bastarz      M
# 44                NaN      F
# 58                NaN      M
# ...               ...    ...
# 1244              NaN      F
# 1245  FANATICS FLAVOR      F
# 1246              NaN      F
# 1267              NaN      F
# 1277              NaN      F
#
# [103 rows x 7 columns]

# %% [markdown]
# En un principio observamos que tenemos algún nombre repetido, pero parece ser que son personas diferentes, ya que tienen fechas de nacimiento diferentes.

# %% [markdown]
# A continuación, como ya hemos dicho, vamos a cambiar el tipo de dato de la columna 'Date of Birth' a tipo fecha.
#
# Además, vamos a calcular una nueva columna con la edad de los fans para un mejor análisis.

# %%
df1['Date of Birth'] = pd.to_datetime(df1['Date of Birth'], errors='coerce')

today = datetime.today()

# Función para calcular la edad
def calculate_age(born):
    if pd.isnull(born):
        return None
    return today.year - born.year - ((today.month, today.day) < (born.month, born.day))

df1['Age'] = df1['Date of Birth'].apply(calculate_age)

df1
# Out:
#           Full Name Korean Name Date of Birth         Group      Country  \
# 0     Seong Hyunwoo         성현우    1996-12-31     Limitless  South Korea
# 1     Jang Wooyoung         장우영    1992-08-28           VAV  South Korea
# 2         Kwon Aeji         권애지    1999-10-25       Hashtag  South Korea
# 3          Lee Ahin         이아인    1999-09-27      MOMOLAND  South Korea
# 4           Go Ahra         고아라    2001-02-21      Favorite  South Korea
# ...             ...         ...           ...           ...          ...
# 1305    Park Heejun         박희준    1997-06-16           VAV  South Korea
# 1306      Bae Jinye         배진예    1994-06-09        LABOUM  South Korea
# 1307     Cho Hyewon         조혜원    2005-05-31       Weeekly  South Korea
# 1308       Bae Juho         백주호    1996-07-04           SF9  South Korea
# 1309      Kim Joomi         김주미    1994-12-08  Ladies' Code  South Korea
#
#      Other Group Gender  Age
# 0            NaN      M   28
# 1            NaN      M   32
# 2            NaN      F   25
# 3            NaN      F   25
# 4            NaN      F   23
# ...          ...    ...  ...
# 1305         NaN      M   27
# 1306       UNI.T      F   30
# 1307         NaN      F   19
# 1308         NaN      M   28
# 1309         NaN      F   30
#
# [1310 rows x 8 columns]

# %% [markdown]
# A continuación vamos a realiar algún gráfico para tener una visión global de lo que nos encontramos.

# %%
fig1=px.histogram(df1, x='Age',
            title='Edades de los Fans',
            color_discrete_sequence=px.colors.qualitative.Bold,
            template='plotly_white')

fig1.update_layout(
    font = {
        'family':"Times New Roman",
        'size':16,
        'color':'black'
        },
    title={
        'y':0.95,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top',
        'font_family':"Times New Roman",
        'font_size':25,
        'font_color':'black'},
    showlegend=True,
    bargap=0.01)

fig1.update_yaxes(
        title_font = {'size':20, 'color':'black'}, # Customización Elementos del Título.
        ticks="outside", tickwidth=2, tickcolor='black', ticklen=5, # Customización de los Ticks.
        showline=True, linewidth=2, linecolor='black', # Customizacion Axis Line (lineas de ejes)
        showgrid=True, gridwidth=0.1, gridcolor='grey', griddash='dash', minor_griddash=None, # Customización del GRID
        zeroline=False, zerolinewidth=2, zerolinecolor='black', # Customizando 0.
        range=[None, None]
        )

fig1.update_xaxes(
        title_font = {'size':20, 'color':'black'}, # Customización Elementos del Título.
        ticks="outside", tickwidth=2, tickcolor='black', ticklen=10, # Customización de los Ticks.
        showline=True, linewidth=2, linecolor='black', # Customizacion Axis Line (lineas de ejes)
        showgrid=True, gridwidth=0.1, gridcolor='grey', griddash='dash', minor_griddash="dot",  # Customización del GRID
        zeroline=False, zerolinewidth=2, zerolinecolor='black', # Customizando 0.
        range=[None, None]
        )
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6ee21d2b-b324-42c8-8ba3-29eda96bf0f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ee21d2b-b324-42c8-8ba3-29eda96bf0f3")) {                    Plotly.newPlot(                        "6ee21d2b-b324-42c8-8ba3-29eda96bf0f3",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Age=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"rgb(127, 60, 141)","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[28,32,25,25,23,33,28,35,33,24,28,34,25,32,24,26,24,23,30,25,24,25,31,23,33,27,25,28,34,31,28,29,32,22,25,29,32,27,27,32,32,30,35,24,25,23,32,23,23,23,31,27,29,28,30,32,35,37,29,33,30,40,31,24,23,29,25,34,25,38,29,26,27,32,37,33,25,30,27,25,25,29,28,25,22,23,26,27,24,22,27,20,24,25,24,28,26,27,25,25,31,31,29,33,28,24,28,34,32,31,24,32,26,23,28,24,25,34,34,23,27,33,28,31,25,33,33,34,24,29,31,23,27,31,32,35,30,28,31,29,31,26,19,34,25,29,25,27,23,28,31,28,26,24,40,31,31,27,29,24,28,26,33,25,24,29,23,25,28,27,28,21,25,20,26,28,27,33,25,38,26,29,31,35,25,26,32,32,24,22,31,34,33,35,29,25,28,21,22,22,30,30,32,32,26,33,26,34,26,22,24,28,36,28,34,34,29,25,25,27,32,38,33,28,31,32,27,27,26,22,25,36,27,34,22,26,24,26,27,32,29,37,24,36,37,37,35,25,32,30,25,25,37,23,34,33,36,31,23,34,33,27,32,30,26,31,24,26,28,27,23,24,30,35,25,24,27,36,27,22,29,24,29,33,22,39,27,30,25,30,28,27,24,27,24,40,27,24,31,34,21,28,28,25,32,30,27,31,33,26,29,24,30,24,27,20,27,26,28,31,24,27,30,41,35,28,24,29,28,28,30,27,19,29,30,35,29,28,30,34,23,23,32,30,31,34,25,26,27,30,33,28,33,26,22,31,29,29,21,24,26,30,26,29,29,29,22,25,33,28,25,31,32,28,24,25,33,34,31,22,22,23,24,31,30,32,31,31,25,25,34,24,25,30,30,35,33,26,35,35,29,31,32,37,27,33,30,26,27,32,24,24,26,25,26,25,25,31,25,35,32,29,25,23,30,23,25,26,26,33,28,28,23,22,30,31,29,31,30,36,33,30,27,31,26,34,30,24,29,32,24,30,27,28,32,27,23,29,20,32,28,34,23,27,30,26,33,38,36,24,29,25,30,24,27,27,27,28,30,31,43,25,25,35,27,33,28,28,24,27,29,24,37,30,22,31,20,28,30,23,32,35,30,35,31,29,32,25,34,20,21,27,26,25,24,24,29,27,34,34,29,28,32,28,29,26,32,27,29,28,34,23,26,23,27,22,33,28,24,20,33,30,24,27,25,30,30,30,21,34,24,26,35,22,33,24,30,36,26,24,28,31,34,29,22,35,30,29,33,26,26,29,28,24,34,32,22,34,34,29,34,25,28,25,30,37,29,28,29,27,29,23,25,29,28,27,30,33,36,41,24,25,29,27,24,33,26,25,34,22,31,32,35,26,24,31,23,22,24,27,26,32,29,30,44,30,27,26,39,23,25,21,23,24,30,29,25,32,29,26,32,33,36,26,33,26,37,32,29,32,31,25,29,29,30,26,33,34,28,24,28,23,27,26,34,30,29,29,36,32,29,27,23,27,30,29,36,26,23,37,34,24,32,31,23,29,24,25,33,26,33,29,32,35,36,26,28,27,41,22,34,31,24,31,21,27,27,35,27,24,32,23,28,28,28,30,27,33,24,25,22,20,27,31,34,31,23,30,25,31,23,36,23,20,28,26,27,24,30,29,25,28,32,29,33,27,31,27,25,31,26,25,27,33,32,22,22,33,32,34,31,33,25,29,24,30,33,30,21,23,23,23,20,34,27,31,30,20,31,24,28,29,34,39,34,30,33,24,26,43,33,28,24,31,27,30,29,33,28,22,33,26,32,27,29,23,34,33,30,25,29,23,31,24,29,33,23,24,33,28,36,32,43,29,29,29,26,28,26,27,36,33,30,25,35,26,23,24,36,35,33,31,32,31,47,26,38,24,42,35,24,31,29,28,33,23,29,26,24,29,28,26,23,25,30,27,25,26,27,33,33,27,28,26,29,30,37,23,29,27,29,28,28,28,22,26,28,22,25,28,32,25,31,29,31,31,32,28,24,25,28,30,30,26,25,28,25,28,24,22,29,32,31,28,33,24,25,28,30,30,26,30,21,29,24,24,29,30,27,25,34,30,34,36,27,22,24,28,29,28,37,32,25,30,24,32,32,23,26,26,26,24,28,34,29,30,28,36,30,28,23,33,34,26,33,39,29,24,32,25,25,26,32,38,29,25,26,29,36,38,23,29,22,25,21,25,30,38,33,25,31,33,27,35,23,31,28,24,29,26,20,28,24,25,35,26,23,34,21,28,23,29,28,30,37,26,32,28,33,33,30,29,30,25,26,31,24,33,36,32,27,26,28,30,30,23,23,35,25,28,29,31,31,30,32,35,39,34,34,21,30,33,2 ...

# %%
df_pie = pd.DataFrame(df1.groupby(['Country']).size().reset_index(name='Total'))

fig2 = px.pie(df_pie, values='Total', names='Country',
             title='Total de usuarios de cada país',
              color_discrete_sequence=px.colors.qualitative.Bold,
              template='plotly_white'
             )
fig2.update_layout(
    font = {
        'family':"Times New Roman",
        'size':16,
        'color':'black'
        },
    title={
        'y':0.95,
        'x':0.5,
        'xanchor': 'left',
        'yanchor': 'top',
        'font_family':"Times New Roman",
        'font_size':25,
        'font_color':'black'},
    showlegend=True,
    bargap=0.01)

fig2.update_yaxes(
        title_font = {'size':20, 'color':'black'}, # Customización Elementos del Título.
        ticks="outside", tickwidth=2, tickcolor='black', ticklen=5, # Customización de los Ticks.
        showline=True, linewidth=2, linecolor='black', # Customizacion Axis Line (lineas de ejes)
        showgrid=True, gridwidth=0.1, gridcolor='grey', griddash='dash', minor_griddash=None, # Customización del GRID
        zeroline=False, zerolinewidth=2, zerolinecolor='black', # Customizando 0.
        range=[None, None]
        )

fig2.update_xaxes(
        title_font = {'size':20, 'color':'black'}, # Customización Elementos del Título.
        ticks="outside", tickwidth=2, tickcolor='black', ticklen=10, # Customización de los Ticks.
        showline=True, linewidth=2, linecolor='black', # Customizacion Axis Line (lineas de ejes)
        showgrid=True, gridwidth=0.1, gridcolor='grey', griddash='dash', minor_griddash="dot",  # Customización del GRID
        zeroline=False, zerolinewidth=2, zerolinecolor='black', # Customizando 0.
        range=[None, None]
        )
fig2.show();
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b1e09153-f634-4998-9a15-c5be2e996333" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b1e09153-f634-4998-9a15-c5be2e996333")) {                    Plotly.newPlot(                        "b1e09153-f634-4998-9a15-c5be2e996333",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Country=%{label}\u003cbr\u003eTotal=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Australia","Canada","China","Hong Kong","Indonesia","Japan","Malaysia","Philippines","South Korea","Taiwan","Thailand","USA"],"legendgroup":"","name":"","showlegend":true,"values":[1,5,39,4,2,27,1,1,1204,6,6,14],"type":"pie"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"tick ...

# %%
fig3=px.histogram(df1, x='Gender',
            color='Gender',
            title='Hombres y Mujeres',
            color_discrete_sequence=px.colors.qualitative.Bold,
            template='plotly_white')

fig3.update_layout(
    font = {
        'family':"Times New Roman",
        'size':16,
        'color':'black'
        },
    title={
        'y':0.95,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top',
        'font_family':"Times New Roman",
        'font_size':25,
        'font_color':'black'},
    showlegend=True,
    bargap=0.01)

fig3.update_yaxes(
        title_font = {'size':20, 'color':'black'}, # Customización Elementos del Título.
        ticks="outside", tickwidth=2, tickcolor='black', ticklen=5, # Customización de los Ticks.
        showline=True, linewidth=2, linecolor='black', # Customizacion Axis Line (lineas de ejes)
        showgrid=True, gridwidth=0.1, gridcolor='grey', griddash='dash', minor_griddash=None, # Customización del GRID
        zeroline=False, zerolinewidth=2, zerolinecolor='black', # Customizando 0.
        range=[None, None]
        )

fig3.update_xaxes(
        title_font = {'size':20, 'color':'black'}, # Customización Elementos del Título.
        ticks="outside", tickwidth=2, tickcolor='black', ticklen=10, # Customización de los Ticks.
        showline=True, linewidth=2, linecolor='black', # Customizacion Axis Line (lineas de ejes)
        showgrid=True, gridwidth=0.1, gridcolor='grey', griddash='dash', minor_griddash="dot",  # Customización del GRID
        zeroline=False, zerolinewidth=2, zerolinecolor='black', # Customizando 0.
        range=[None, None]
        )
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="316d29c4-7cde-4720-bb12-fae3d02bdabf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("316d29c4-7cde-4720-bb12-fae3d02bdabf")) {                    Plotly.newPlot(                        "316d29c4-7cde-4720-bb12-fae3d02bdabf",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Gender=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"M","marker":{"color":"rgb(127, 60, 141)","pattern":{"shape":""}},"name":"M","offsetgroup":"M","orientation":"v","showlegend":true,"x":["M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Gender=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"F","marker":{"color":"rgb(17, 165, 121)","pattern":{"shape":""}},"name":"F","offsetgroup":"F","orientation":"v","showlegend":true,"x":["F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F" ...

# %% [markdown]
# Para realizar los gráficos hemso utilizado la librería interactiva Plotly, que nos permite, además de visualizar los datos de forma elegante, ahorrarnos algún cáclulo externo.
#
# - En el primer gráfico podemos ver como las edades de los usuarios se encuentran comprendidas entre los 19 y los 47 años, siendo entre los 24 y los 30 años donde se encuentran gran cantidad de los fans.
# - En el segundo gráfico podemos observar que los fans provienen de 12 países distintos, pero que la gran mayoría de los usuarios son de Corea del Sur.
# - En el tercer gráfico hemos comprobado la proporción de hombres y mujeres en la base de datos. Podemos ver que es bastante homogénea en cuanto a género teniendo un total de 676 hombres y 634 mujeres.

# %% [markdown]
# A continuación vamos a comprobar cuantos grupos únicos tenemos en el dataset como favoritos. Además de los segundos grupos favoritos.
#
# Esto lo hacemos para conocer los gustos de los fans para tenerlo en cuenta a la hora de hacer nuestro festival.

# %%
grupos=list(df1['Group'].dropna().unique())
print(f' Grupos favoritos: ',len(grupos))
print(grupos)
# Out:
#  Grupos favoritos:  208
# ['Limitless', 'VAV', 'Hashtag', 'MOMOLAND', 'Favorite', 'Dal Shabet', 'P.O.P', 'Pink Fantasy', 'Everglow', 'Hello Venus', 'CRAVITY', 'f(x)', 'GWSN', 'VARSITY', 'Tahiti', 'RedSquare', 'MIXX', 'Oh My Girl', "NU'EST", 'Treasure', "Ladies' Code", 'NATURE', 'ENOi', 'Block B', 'Topp Dogg', '14U', 'Lovelyz', 'Hinapia', 'NeonPunch', 'EXO', 'GOT7', 'Stray Kids', 'B1A4', '1TEAM', 'DUSTIN', 'ELRIS', 'Cignature', 'B.I.G', 'TXT', 'ANS', 'MCND', 'Hot Blood Youth', 'MONT', 'UP10TION', 'Pungdeng-E', 'KARD', 'SPICA', 'iKON', 'SIGNAL', '2NE1', 'Apink', 'Golden Child', 'Cosmic Girls', 'Dreamnote', 'SISTAR', 'Cherry Bullet', 'T-ara', 'CIX', 'VICTON', 'Teen Top', 'Fiestar', 'CROSS GENE', 'N.Flying', 'Bonus Baby', 'MYNAME', 'APRIL', 'FANATICS', 'ITZY', 'IZ*ONE', 'CRAXY', 'DIA', 'Busters', 'Twice', 'fromis_9', 'MELODYDAY', 'A.C.E', 'TOO', 'UNVS', 'BtoB', '24K', 'SF9', 'AoA', '2PM', '100%', 'D-CRUNCH', 'NCT', 'Ho1iday', 'Crayon Pop', 'LOONA', 'Newkidd', 'Onewe', 'Sonamoo', 'AB6IX', 'B.A.P', 'BIGBANG', '2EYES', 'Rocket Punch', 'Dreamcatcher', 'Matilda', 'Wanna One', 'ARIAZ', 'Berry Good', 'Blady', 'Rockit Girl', 'SECRET NUMBER', 'Seventeen', 'X1', 'HISTORY', 'Super Junior', 'JBJ', 'Verivery', 'Boyfriend', 'ZE:A', 'Spectrum', 'KNK', 'Infinite', 'Highlight', 'DAY6', 'Weki Meki', '1the9', 'ONF', 'After School', 'U-KISS', 'CLC', 'Girlkind', 'The Boyz', 'We In The Zone', 'Bigflo', 'Two X', 'Gfriend', 'Brave Girls', 'Playback', 'Highteen', 'TheEastLight', 'ASTRO', 'miss A', 'MBLAQ', 'Gate9', 'Brown Eyed Girls', '4minute', 'Stellar', 'IM', 'ARGON', 'H.U.B', 'KARA', 'Gugudan', 'LABOUM', 'Davichi', 'BESTie', '3YE', 'TRCNG', 'I.B.I', 'SECRET', 'EXID', 'Lusty', 'Good Day', '4TEN', 'Super Junior-M', 'HOTSHOT', 'VIXX', 'FTISLAND', 'Astin', 'ATEEZ', 'PENTAGON', 'Oneus', 'Mamamoo', '9Muses', "Girl's Day", 'Wonder Girls', 'SNSD', 'MONSTA X', 'UNI.T', 'IZ', 'Romeo', 'G-reyish', 'D1CE', 'IN2IT', 'Rainbow', 'Red Velvet', 'BTS', 'Dongkiz', 'Weeekly', 'JYJ', '15&', 'BLACKPINK', 'Wassup', 'WINNER', 'TEEN TEEN', 'S#aFLA', 'Bolbbalgan4', 'SHINee', 'CNBLUE', 'BVNDIT', 'OnlyOneOf', 'BADKIZ', 'JBJ95', 'GIDONGDAE', 'B.O.Y', 'Pristin', 'Purplebeck', 'Nature', 'woo!ah!', 'TVXQ', 'Honey Popcorn', '(G)I-DLE', 'Boys Republic', 'SNUPER', 'UNIQ']

# %%
otros_grupos=list(df1['Other Group'].dropna().unique())
print(f' Otros grupos favoritos: ',len(otros_grupos))
print(otros_grupos)
# Out:
#  Otros grupos favoritos:  55
# ["NU'EST W", 'Bastarz', 'EXO-CBX, SuperM', '3RACHA', 'SPICA-S', 'C.I.V.A, I.B.I', 'I.O.I', 'UNB', 'EXO-CBX', 'NCT Dream', 'FANATICS FLAVOR', 'Loona Odd Eye Circle', 'Loona yyxy', 'Super Junior-M', 'MXM', 'Infinite H', 'I.O.I, WJMK', 'NCT U, NCT 127', 'UNI.T', 'Pristin V', 'GD&TOP', '2YOON', 'NCT 127, NCT Dream', 'IM', 'Loona 1/3', '9MUSES A', 'Gugudan Oguogu', 'Big Byung', 'Troublemaker', 'Rainbow Blaxx, Rainbow Pixie', 'Rainbow Blaxx', 'AOA BLACK', 'Rainbow Pixie', 'NCT 127', 'BinChaenHyunSeuS', 'SuperM', 'Toheart', 'JBJ', 'C.I.V.A', 'I.O.I, Pristin V', 'Infinite F', 'VIXX LR', 'Orange Caramel', 'WJMK', 'NCT U, NCT 127, NCT Dream, SuperM', "NU'EST", 'TTS', 'VICTON', 'UNIQ', 'L.U.B', 'HOTSHOT', 'TTS, Oh!GG', 'NCT U, NCT 127,SuperM', 'NCT U,SuperM', 'UP10TION']

# %%
df1.groupby('Group').size().sort_values(ascending=False)
# Out:
# Group
# NCT               18
# 14U               14
# Cosmic Girls      13
# Seventeen         13
# IZ*ONE            12
#                   ..
# 15&                2
# Super Junior-M     2
# Good Day           1
# Nature             1
# JBJ95              1
# Length: 208, dtype: int64

# %%
df1.groupby('Other Group').size().sort_values(ascending=False)
# Out:
# Other Group
# Super Junior-M                       6
# Loona 1/3                            5
# NCT Dream                            5
# SPICA-S                              4
# 9MUSES A                             4
# UNI.T                                4
# NU'EST W                             4
# Loona yyxy                           4
# Pristin V                            3
# 3RACHA                               3
# Infinite F                           3
# NCT U, NCT 127                       3
# Orange Caramel                       3
# NCT 127                              3
# FANATICS FLAVOR                      3
# SuperM                               3
# Big Byung                            3
# Bastarz                              3
# Loona Odd Eye Circle                 3
# Rainbow Blaxx                        2
# Rainbow Blaxx, Rainbow Pixie         2
# TTS                                  2
# Toheart                              2
# MXM                                  2
# VIXX LR                              2
# 2YOON                                2
# WJMK                                 2
# I.O.I, Pristin V                     2
# GD&TOP                               2
# JBJ                                  2
# Gugudan Oguogu                       2
# I.O.I                                2
# I.O.I, WJMK                          2
# Infinite H                           2
# AOA BLACK                            2
# EXO-CBX                              2
# BinChaenHyunSeuS                     1
# UNB                                  1
# TTS, Oh!GG                           1
# UNIQ                                 1
# UP10TION                             1
# Troublemaker                         1
# VICTON                               1
# C.I.V.A                              1
# L.U.B                                1
# C.I.V.A, I.B.I                       1
# EXO-CBX, SuperM                      1
# HOTSHOT                              1
# NU'EST                               1
# NCT U,SuperM                         1
# NCT U, NCT 127,SuperM                1
# NCT U, NCT 127, NCT Dream, SuperM    1
# IM                                   1
# NCT 127, NCT Dream                   1
# Rainbow Pixie                        1
# dtype: int64

# %% [markdown]
# Vamos a realizar a continuación una lista con los grupos favoritos y segundos favoritos, para ello primero comprobamos si se repite algún grupo para poder tener los nombres únicos.

# %%
ambos=[]
nuevos_grupos=[]
for i in otros_grupos:
  if i in grupos:
    ambos.append(i)
  else:
    nuevos_grupos.append(i)

print(f'Grupos nuevos entre los otros favoritos: ',len(nuevos_grupos))
# Out:
# Grupos nuevos entre los otros favoritos:  46

# %%
grupos=grupos+nuevos_grupos
print(f'Grupos favoritos: ', len(grupos))
print(grupos)
# Out:
# Grupos favoritos:  254
# ['Limitless', 'VAV', 'Hashtag', 'MOMOLAND', 'Favorite', 'Dal Shabet', 'P.O.P', 'Pink Fantasy', 'Everglow', 'Hello Venus', 'CRAVITY', 'f(x)', 'GWSN', 'VARSITY', 'Tahiti', 'RedSquare', 'MIXX', 'Oh My Girl', "NU'EST", 'Treasure', "Ladies' Code", 'NATURE', 'ENOi', 'Block B', 'Topp Dogg', '14U', 'Lovelyz', 'Hinapia', 'NeonPunch', 'EXO', 'GOT7', 'Stray Kids', 'B1A4', '1TEAM', 'DUSTIN', 'ELRIS', 'Cignature', 'B.I.G', 'TXT', 'ANS', 'MCND', 'Hot Blood Youth', 'MONT', 'UP10TION', 'Pungdeng-E', 'KARD', 'SPICA', 'iKON', 'SIGNAL', '2NE1', 'Apink', 'Golden Child', 'Cosmic Girls', 'Dreamnote', 'SISTAR', 'Cherry Bullet', 'T-ara', 'CIX', 'VICTON', 'Teen Top', 'Fiestar', 'CROSS GENE', 'N.Flying', 'Bonus Baby', 'MYNAME', 'APRIL', 'FANATICS', 'ITZY', 'IZ*ONE', 'CRAXY', 'DIA', 'Busters', 'Twice', 'fromis_9', 'MELODYDAY', 'A.C.E', 'TOO', 'UNVS', 'BtoB', '24K', 'SF9', 'AoA', '2PM', '100%', 'D-CRUNCH', 'NCT', 'Ho1iday', 'Crayon Pop', 'LOONA', 'Newkidd', 'Onewe', 'Sonamoo', 'AB6IX', 'B.A.P', 'BIGBANG', '2EYES', 'Rocket Punch', 'Dreamcatcher', 'Matilda', 'Wanna One', 'ARIAZ', 'Berry Good', 'Blady', 'Rockit Girl', 'SECRET NUMBER', 'Seventeen', 'X1', 'HISTORY', 'Super Junior', 'JBJ', 'Verivery', 'Boyfriend', 'ZE:A', 'Spectrum', 'KNK', 'Infinite', 'Highlight', 'DAY6', 'Weki Meki', '1the9', 'ONF', 'After School', 'U-KISS', 'CLC', 'Girlkind', 'The Boyz', 'We In The Zone', 'Bigflo', 'Two X', 'Gfriend', 'Brave Girls', 'Playback', 'Highteen', 'TheEastLight', 'ASTRO', 'miss A', 'MBLAQ', 'Gate9', 'Brown Eyed Girls', '4minute', 'Stellar', 'IM', 'ARGON', 'H.U.B', 'KARA', 'Gugudan', 'LABOUM', 'Davichi', 'BESTie', '3YE', 'TRCNG', 'I.B.I', 'SECRET', 'EXID', 'Lusty', 'Good Day', '4TEN', 'Super Junior-M', 'HOTSHOT', 'VIXX', 'FTISLAND', 'Astin', 'ATEEZ', 'PENTAGON', 'Oneus', 'Mamamoo', '9Muses', "Girl's Day", 'Wonder Girls', 'SNSD', 'MONSTA X', 'UNI.T', 'IZ', 'Romeo', 'G-reyish', 'D1CE', 'IN2IT', 'Rainbow', 'Red Velvet', 'BTS', 'Dongkiz', 'Weeekly', 'JYJ', '15&', 'BLACKPINK', 'Wassup', 'WINNER', 'TEEN TEEN', 'S#aFLA', 'Bolbbalgan4', 'SHINee', 'CNBLUE', 'BVNDIT', 'OnlyOneOf', 'BADKIZ', 'JBJ95', 'GIDONGDAE', 'B.O.Y', 'Pristin', 'Purplebeck', 'Nature', 'woo!ah!', 'TVXQ', 'Honey Popcorn', '(G)I-DLE', 'Boys Republic', 'SNUPER', 'UNIQ', "NU'EST W", 'Bastarz', 'EXO-CBX, SuperM', '3RACHA', 'SPICA-S', 'C.I.V.A, I.B.I', 'I.O.I', 'UNB', 'EXO-CBX', 'NCT Dream', 'FANATICS FLAVOR', 'Loona Odd Eye Circle', 'Loona yyxy', 'MXM', 'Infinite H', 'I.O.I, WJMK', 'NCT U, NCT 127', 'Pristin V', 'GD&TOP', '2YOON', 'NCT 127, NCT Dream', 'Loona 1/3', '9MUSES A', 'Gugudan Oguogu', 'Big Byung', 'Troublemaker', 'Rainbow Blaxx, Rainbow Pixie', 'Rainbow Blaxx', 'AOA BLACK', 'Rainbow Pixie', 'NCT 127', 'BinChaenHyunSeuS', 'SuperM', 'Toheart', 'C.I.V.A', 'I.O.I, Pristin V', 'Infinite F', 'VIXX LR', 'Orange Caramel', 'WJMK', 'NCT U, NCT 127, NCT Dream, SuperM', 'TTS', 'L.U.B', 'TTS, Oh!GG', 'NCT U, NCT 127,SuperM', 'NCT U,SuperM']

# %% [markdown]
# Para terminar con esta base de datos la información más importante que vamos a rescatar es la lista de los grupos favoritos de los fans. Esta lista la vamos a tener muy en cuenta a la hora de realizar nuestro festival de k-pop.

# %% [markdown]
# A continuación vamos a analizar la base de datos de kpop_idols_boy_groups. Esta base de datos contiene la información de las bandas de música de k-pop masculinas.

# %%
df2=pd.read_csv('/content/kpop_idols_boy_groups.csv')
df2
# Out:
#                Name Short Korean Name       Debut       Company  Members  \
# 0              100%   NaN        백퍼센트  2012-09-18     TOP Media        4
# 1               14U   NaN         원포유  2017-04-17            BG       14
# 2             1the9   NaN        원더나인  2019-02-09           MBK        9
# 3               24K   NaN        투포케이  2012-09-06        Choeun        8
# 4               2AM   NaN        투에이엠  2008-06-21  JYP, Big Hit        4
# ..              ...   ...         ...         ...           ...      ...
# 142        VROMANCE   NaN        브로맨스  2016-06-12           RBW        4
# 143       Wanna One   NaN         워너원  2017-08-07           YMC       11
# 144  We In The Zone   NaN        위인더존  2019-05-27         Choon        5
# 145          WINNER   NaN          위너  2014-08-12            YG        4
# 146            ZE:A   NaN     제국의 아이들  2010-01-07   Star Empire        9
#
#      Orig. Memb. Fanclub Name  Active
# 0              7   Perfection     Yes
# 1             14          NaN     Yes
# 2              9          NaN     Yes
# 3              6          24U     Yes
# 4              4         I Am      No
# ..           ...          ...     ...
# 142            4          NaN     Yes
# 143           11     Wannable      No
# 144            5          NaN     Yes
# 145            5          Ace     Yes
# 146            9   ZE:A Style  Hiatus
#
# [147 rows x 9 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          147 non-null    object
#  1   Short         18 non-null     object
#  2   Korean Name   147 non-null    object
#  3   Debut         147 non-null    object
#  4   Company       146 non-null    object
#  5   Members       147 non-null    int64
#  6   Orig. Memb.   147 non-null    int64
#  7   Fanclub Name  61 non-null     object
#  8   Active        147 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 10.5+ KB

# %% [markdown]
# En esta base de datos contamos con 147 grupos masculinos distintos y 9 columnas.
#
# Observamos que la columna 'Short' contienen una gran cantidad de nulos y es información no relevante para nuestro análisis, por lo que la vamos a eliminar, y la columna 'Orig. Memb.' también la vamos a eliminar por el mismo motivo. Por lo que nos vamos a quedar con las columnas siguientes:
#
# - 'Name' y 'Korean Name' que son el nombre de la banda.
# - 'Debut' que corresponde con el debut de la banda. Observamos que el tipo de dato es object, por lo que lo cambiaremos a tipo fecha.
# - 'Company' que corresponde con la discográfica de la banda.
# - 'Members' que corresponde con los miembros con los que cuenta la banda.
# - 'Fanclub Name' que es el nombre del club de fans de la banda si tienen.
# - 'Active' que nos dice si la banda sigue en activo o por lo contrario ya no actúan.

# %%
df2['Debut'] = pd.to_datetime(df2['Debut'], errors='coerce')
df2=df2.drop(['Short','Orig. Memb.'],axis=1)
df2
# Out:
#                Name Korean Name      Debut       Company  Members  \
# 0              100%        백퍼센트 2012-09-18     TOP Media        4
# 1               14U         원포유 2017-04-17            BG       14
# 2             1the9        원더나인 2019-02-09           MBK        9
# 3               24K        투포케이 2012-09-06        Choeun        8
# 4               2AM        투에이엠 2008-06-21  JYP, Big Hit        4
# ..              ...         ...        ...           ...      ...
# 142        VROMANCE        브로맨스 2016-06-12           RBW        4
# 143       Wanna One         워너원 2017-08-07           YMC       11
# 144  We In The Zone        위인더존 2019-05-27         Choon        5
# 145          WINNER          위너 2014-08-12            YG        4
# 146            ZE:A     제국의 아이들 2010-01-07   Star Empire        9
#
#     Fanclub Name  Active
# 0     Perfection     Yes
# 1            NaN     Yes
# 2            NaN     Yes
# 3            24U     Yes
# 4           I Am      No
# ..           ...     ...
# 142          NaN     Yes
# 143     Wannable      No
# 144          NaN     Yes
# 145          Ace     Yes
# 146   ZE:A Style  Hiatus
#
# [147 rows x 7 columns]

# %% [markdown]
# A continuación vamos a ver cuantos miembros tienen los grupos mediante un histograma, para hacernos una idea de como se distribuye.

# %%
fig4=px.histogram(df2, x='Members',
            title='Miembros en las boy bands',
            color_discrete_sequence=px.colors.qualitative.Bold,
            template='plotly_white')

fig4.update_layout(
    font = {
        'family':"Times New Roman",
        'size':16,
        'color':'black'
        },
    title={
        'y':0.95,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top',
        'font_family':"Times New Roman",
        'font_size':25,
        'font_color':'black'},
    showlegend=True,
    bargap=0.01)

fig4.update_yaxes(
        title_font = {'size':20, 'color':'black'}, # Customización Elementos del Título.
        ticks="outside", tickwidth=2, tickcolor='black', ticklen=5, # Customización de los Ticks.
        showline=True, linewidth=2, linecolor='black', # Customizacion Axis Line (lineas de ejes)
        showgrid=True, gridwidth=0.1, gridcolor='grey', griddash='dash', minor_griddash=None, # Customización del GRID
        zeroline=False, zerolinewidth=2, zerolinecolor='black', # Customizando 0.
        range=[None, None]
        )

fig4.update_xaxes(
        title_font = {'size':20, 'color':'black'}, # Customización Elementos del Título.
        ticks="outside", tickwidth=2, tickcolor='black', ticklen=10, # Customización de los Ticks.
        showline=True, linewidth=2, linecolor='black', # Customizacion Axis Line (lineas de ejes)
        showgrid=True, gridwidth=0.1, gridcolor='grey', griddash='dash', minor_griddash="dot",  # Customización del GRID
        zeroline=False, zerolinewidth=2, zerolinecolor='black', # Customizando 0.
        range=[None, None]
        )
fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8288e43a-69e7-4952-b921-ad0a501c9c63" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8288e43a-69e7-4952-b921-ad0a501c9c63")) {                    Plotly.newPlot(                        "8288e43a-69e7-4952-b921-ad0a501c9c63",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Members=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"rgb(127, 60, 141)","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[4,14,9,8,4,6,3,5,5,4,6,5,5,6,8,6,4,5,5,3,2,4,5,5,6,7,7,7,6,5,7,7,6,4,5,4,9,5,9,7,5,9,7,9,2,4,5,10,7,9,5,5,6,4,4,5,2,4,5,6,5,7,6,5,4,6,2,5,3,4,5,4,4,7,4,3,7,5,4,3,5,6,6,7,7,2,5,6,6,5,4,18,7,9,6,5,6,6,9,3,7,5,7,5,5,13,9,3,4,6,4,6,6,7,5,9,11,5,7,5,12,6,5,10,5,2,10,7,3,2,5,6,9,5,10,12,7,7,5,7,6,4,4,11,5,4,9],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}] ...

# %% [markdown]
# Podemos ver como, aunque la mayoría de grupos tienen un número de miembros entre 4 y 7, hay grupos que cuentan con más de 10 miembros, e incluso un grupo que cuenta con 18 miembros.

# %% [markdown]
# Para realizar después nosotros la selección de grupos con los que vamos a contar en el festival primero vamos a hacer 2 filtros.
#
# Para empezar, creeamos que un grupo con club de fans atrae a más gente que uno sin club de fans, y lo que nosotros buscamos en nustro festival es darle visibilidad al género del K-Pop, por lo que nos vamos a quedar únicamente con los grupos con club de fans.
#
# Por otra parte, es importante saber si el grupo sigue en activo o por lo contrario ya no da conciertos, por lo que nos vamos a quedar solo con los grupos en activo, porque lo que nos interesa es que toquen en nustro festival.

# %%
df2_filtrado=df2.dropna(subset=['Fanclub Name'])
df2_filtrado=df2_filtrado.loc[df2_filtrado['Active']=='Yes']
df2_filtrado.head()
# Out:
#      Name Korean Name      Debut    Company  Members Fanclub Name Active
# 0    100%        백퍼센트 2012-09-18  TOP Media        4   Perfection    Yes
# 3     24K        투포케이 2012-09-06     Choeun        8          24U    Yes
# 5     2PM         투피엠 2008-07-04        JYP        6      Hottest    Yes
# 8   A.C.E         에이스 2017-05-23       Beat        5       Choice    Yes
# 11  AB6IX       에이비식스 2019-05-22  Brand New        5        ABNEW    Yes

# %%
df2_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45 entries, 0 to 145
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          45 non-null     object
#  1   Korean Name   45 non-null     object
#  2   Debut         45 non-null     datetime64[ns]
#  3   Company       45 non-null     object
#  4   Members       45 non-null     int64
#  5   Fanclub Name  45 non-null     object
#  6   Active        45 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 2.8+ KB

# %% [markdown]
# A continuación nos vamos a quedar con los nombres de las boy bands filtradas.

# %%
boy_groups_cf=list(df2_filtrado['Name'].unique())
print(f'Número de boy groups en activo y con club de fans: ',len(boy_groups_cf))
# Out:
# Número de boy groups en activo y con club de fans:  45

# %% [markdown]
# En el primer dataset hemos sacado el nombre de 254 grupos favoritos entre los fans del k-pop, ahora vamos a comprobar cuantos de los 45 grupos masculinos aparecen en estos grupos favoritos.

# %%
favoritos_h_cf=[]
no_fh_cf=[]
for i in boy_groups_cf:
  if i in grupos:
    favoritos_h_cf.append(i)
  else:
    no_fh_cf.append(i)
print(f'Grupos favoritos:' ,len(favoritos_h_cf))
print(f'Grupos no favoritos:' ,len(no_fh_cf))
# Out:
# Grupos favoritos: 38
# Grupos no favoritos: 7

# %% [markdown]
# Como resumen de este dataset nos vamos a quedar con que contamos con 38 bandas masculinas de k-pop con club de fans, en activo y que estan entre las favoritas de los fans del k-pop.

# %% [markdown]
# A continuación vamos a hacer lo mismo pero con el dataset kpop_idols_girl_groups. Esta base de datos contiene la información de los grupos de k-pop femeninos.

# %%
df3=pd.read_csv('/content/kpop_idols_girl_groups.csv')
df3
# Out:
#              Name         Short Korean Name       Debut    Company  Members  \
# 0        (G)I-DLE           NaN     (여자)아이들  2018-05-02       Cube        6
# 1             15&           NaN       피프틴앤드  2012-10-05        JYP        2
# 2           2EYES           NaN        투아이즈  2013-07-20    SidusHQ        4
# 3            2NE1           NaN        투애니원  2009-05-06         YG        4
# 4             3YE           NaN        써드아이  2019-05-21         GH        3
# ..            ...           ...         ...         ...        ...      ...
# 147      We Girls           NaN         위걸스  2018-08-31  Afternoon        8
# 148     Weki Meki          WeMe        위키미키  2017-08-08   Fantagio        8
# 149          WJSN  Cosmic Girls        우주소녀  2016-02-25   Starship       13
# 150  Wonder Girls            WG        원더걸스  2007-02-13        JYP        4
# 151    Yellow Bee           NaN         옐로비  2017-11-23  Addiction        5
#
#      Orig. Memb. Fanclub Name Active
# 0              6          NaN    Yes
# 1              2          NaN     No
# 2              5          NaN     No
# 3              4    Blackjack     No
# 4              3          NaN    Yes
# ..           ...          ...    ...
# 147            8          NaN    Yes
# 148            8          NaN    Yes
# 149           12        Ujung    Yes
# 150            5    Wonderful     No
# 151            5          NaN    Yes
#
# [152 rows x 9 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          152 non-null    object
#  1   Short         21 non-null     object
#  2   Korean Name   152 non-null    object
#  3   Debut         152 non-null    object
#  4   Company       152 non-null    object
#  5   Members       152 non-null    int64
#  6   Orig. Memb.   152 non-null    int64
#  7   Fanclub Name  46 non-null     object
#  8   Active        152 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 10.8+ KB

# %% [markdown]
#  Como en el dataset anterior, hay columnas que no son relevantes para nuestro análisis, estas son 'Short' y 'Orig. Memb.', por lo que las vamos a eliminar.
#  Además, también vamos a cambiar el tipo de dato de la columna 'Debut' para que esté en formato fecha y no object.
#
#  Las columnas son exactamente iguales que las del dataset anterior.

# %%
df3['Debut'] = pd.to_datetime(df3['Debut'], errors='coerce')
df3=df3.drop(['Short','Orig. Memb.'],axis=1)
df3
# Out:
#              Name Korean Name      Debut    Company  Members Fanclub Name  \
# 0        (G)I-DLE     (여자)아이들 2018-05-02       Cube        6          NaN
# 1             15&       피프틴앤드 2012-10-05        JYP        2          NaN
# 2           2EYES        투아이즈 2013-07-20    SidusHQ        4          NaN
# 3            2NE1        투애니원 2009-05-06         YG        4    Blackjack
# 4             3YE        써드아이 2019-05-21         GH        3          NaN
# ..            ...         ...        ...        ...      ...          ...
# 147      We Girls         위걸스 2018-08-31  Afternoon        8          NaN
# 148     Weki Meki        위키미키 2017-08-08   Fantagio        8          NaN
# 149          WJSN        우주소녀 2016-02-25   Starship       13        Ujung
# 150  Wonder Girls        원더걸스 2007-02-13        JYP        4    Wonderful
# 151    Yellow Bee         옐로비 2017-11-23  Addiction        5          NaN
#
#     Active
# 0      Yes
# 1       No
# 2       No
# 3       No
# 4      Yes
# ..     ...
# 147    Yes
# 148    Yes
# 149    Yes
# 150     No
# 151    Yes
#
# [152 rows x 7 columns]

# %%
fig5=px.histogram(df3, x='Members',
            title='Miembros en las girl bands',
            color_discrete_sequence=px.colors.qualitative.Bold,
            template='plotly_white')

fig5.update_layout(
    font = {
        'family':"Times New Roman",
        'size':16,
        'color':'black'
        },
    title={
        'y':0.95,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top',
        'font_family':"Times New Roman",
        'font_size':25,
        'font_color':'black'},
    showlegend=True,
    bargap=0.01)

fig5.update_yaxes(
        title_font = {'size':20, 'color':'black'}, # Customización Elementos del Título.
        ticks="outside", tickwidth=2, tickcolor='black', ticklen=5, # Customización de los Ticks.
        showline=True, linewidth=2, linecolor='black', # Customizacion Axis Line (lineas de ejes)
        showgrid=True, gridwidth=0.1, gridcolor='grey', griddash='dash', minor_griddash=None, # Customización del GRID
        zeroline=False, zerolinewidth=2, zerolinecolor='black', # Customizando 0.
        range=[None, None]
        )

fig5.update_xaxes(
        title_font = {'size':20, 'color':'black'}, # Customización Elementos del Título.
        ticks="outside", tickwidth=2, tickcolor='black', ticklen=10, # Customización de los Ticks.
        showline=True, linewidth=2, linecolor='black', # Customizacion Axis Line (lineas de ejes)
        showgrid=True, gridwidth=0.1, gridcolor='grey', griddash='dash', minor_griddash="dot",  # Customización del GRID
        zeroline=False, zerolinewidth=2, zerolinecolor='black', # Customizando 0.
        range=[None, None]
        )
fig5.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="80d79e7d-525b-4cdc-b7c2-ecb4398c8a2e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("80d79e7d-525b-4cdc-b7c2-ecb4398c8a2e")) {                    Plotly.newPlot(                        "80d79e7d-525b-4cdc-b7c2-ecb4398c8a2e",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Members=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"rgb(127, 60, 141)","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[6,2,4,4,3,5,4,4,6,4,6,4,8,5,6,5,6,6,5,5,6,4,4,5,4,4,2,6,5,4,5,5,5,3,3,7,4,5,7,7,2,4,2,4,4,2,4,7,3,7,6,7,5,6,5,5,4,6,6,5,3,9,3,5,7,6,3,4,5,4,5,5,4,10,4,4,8,7,5,7,6,4,4,4,4,5,5,3,3,5,12,4,4,2,4,5,3,7,12,8,5,4,5,4,4,5,3,5,6,6,9,3,7,5,6,8,5,10,3,5,7,5,5,2,4,2,3,6,6,3,6,4,5,5,4,4,4,5,3,3,9,4,8,4,2,5,7,8,8,13,4,5],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogra ...

# %% [markdown]
# Observamos como en los grupos femeninos los miembros van desde los 2 hasta los 13 miembros, aunque lo que más predomina en el dataset son los grupos con 4 o 5 miembros.

# %% [markdown]
# A continuación vamos a realizar los mismos 2 filtros que en el dataset anterior para quedarnos con los grupos en activo y que tienen club de fans.

# %%
df3_filtrado=df3.dropna(subset=['Fanclub Name'])
df3_filtrado=df3_filtrado.loc[df3_filtrado['Active']=='Yes']
df3_filtrado.head()
# Out:
#                 Name Korean Name      Debut Company  Members Fanclub Name  \
# 13               AOA       에이오에이 2012-07-30     FNC        5        ELVIS
# 14             Apink        에이핑크 2011-04-19  Plan A        6   Pink Panda
# 16             April        에이프릴 2015-08-24     DSP        6    Fineapple
# 29  Brown Eyed Girls  브라운 아이드 걸스 2006-03-02  Mystic        4  Everlasting
# 31           Busters        버스터즈 2017-11-27     JTG        5       Bu-Chu
#
#    Active
# 13    Yes
# 14    Yes
# 16    Yes
# 29    Yes
# 31    Yes

# %%
df3_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22 entries, 13 to 149
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          22 non-null     object
#  1   Korean Name   22 non-null     object
#  2   Debut         22 non-null     datetime64[ns]
#  3   Company       22 non-null     object
#  4   Members       22 non-null     int64
#  5   Fanclub Name  22 non-null     object
#  6   Active        22 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 1.4+ KB

# %% [markdown]
# Podemos ver que tenemos 22 grupos femeninos de k-pop en activo y con club de fans.
# A continuación vamos a obtener los nombres de las bandas y las vamos a almacenar como antes.

# %%
girl_groups_cf=list(df3_filtrado['Name'].unique())
print(f'Número de girl groups en activo con club de fans: ',len(girl_groups_cf))
print(girl_groups_cf)
# Out:
# Número de girl groups en activo con club de fans:  22
# ['AOA', 'Apink', 'April', 'Brown Eyed Girls', 'Busters', 'CLC', 'DIA', 'EXID', 'Gfriend', "Girls' Generation", 'GWSN', 'HighSchool', 'ITZY', 'Laboum', 'Lovelyz', 'Mamamoo', 'Oh My Girl', 'PURPLEBECK', 'Sonamoo', 'TWICE', 'Wanna.B', 'WJSN']

# %% [markdown]
# Ahora vamos a hacer como antes y vamos a comprobar cuantos de los 22 grupos anteriores aparecen entre los favoritos de los fans.

# %%
favoritos_m_cf=[]
no_fm_cf=[]
for i in girl_groups_cf:
  if i in grupos:
    favoritos_m_cf.append(i)
  else:
    no_fm_cf.append(i)
print(f'Número de grupos favoritos: ',len(favoritos_m_cf))
print(f'Número de grupos no favoritos: ',len(no_fm_cf))
# Out:
# Número de grupos favoritos:  13
# Número de grupos no favoritos:  9

# %% [markdown]
# Igual que anteriormente, nos vamos a quedar con la lista de los 13 nombres de grupos femeninos de k-pop en activo y con club de fans para posteriormente hacer la selección de los 10 grupos de nuestro festival.

# %% [markdown]
# A continuación vamos a cargar el último dataset.
#
# Este dataset contiene los videos y enlaces de youtube de las canciones de algunos grupos.

# %%
df4=pd.read_csv('/content/kpop_music_videos.csv')
df4
# Out:
#             Date              Artist                      Song Name  \
# 0     2020-05-22             Agust D                      Daechwita
# 1     2020-05-21               Yubin                 yaya (Me Time)
# 2     2020-05-21           OnlyOneOf             Angel (prod. GRAY)
# 3     2020-05-20         Ryu Sujeong                     Tiger Eyes
# 4     2020-05-20               Crush  Mayday feat. Joy (Red Velvet)
# ...          ...                 ...                            ...
# 3767  1994-08-08  Seo Taiji and Boys                       Eternity
# 3768  1993-06-06  Seo Taiji and Boys                    Anyhow Song
# 3769  1993-06-06  Seo Taiji and Boys                         To You
# 3770  1992-03-23  Seo Taiji and Boys                         I Know
# 3771  1992-03-23  Seo Taiji and Boys            You, In The Fantasy
#
#      Korean Name Director                         Video       Type Release
# 0            대취타      NaN  https://youtu.be/qGjAWJ2zWWI   Boy Solo   Major
# 1             넵넵      NaN  https://youtu.be/BJD0arHF_5c  Girl Solo   Major
# 2            NaN      NaN  https://youtu.be/vVTo8p72FxQ        Boy   Major
# 3            NaN      NaN  https://youtu.be/aE6curPGQRY  Girl Solo   Major
# 4           자나깨나      NaN  https://youtu.be/29ycT6fA-Rs   Boy Solo   Major
# ...          ...      ...                           ...        ...     ...
# 3767          영원      NaN  https://youtu.be/74usU0gB7r0        Boy   Minor
# 3768         하여가      NaN  https://youtu.be/L-AxO7EPU8c        Boy   Major
# 3769         너에게      NaN  https://youtu.be/cxIAiAUyvXo        Boy   Minor
# 3770       난 알아요      NaN  https://youtu.be/OEDHEzs5kyk        Boy   Major
# 3771     환상속의 그대      NaN  https://youtu.be/KGcwGoXfUDk        Boy   Minor
#
# [3772 rows x 8 columns]

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3772 entries, 0 to 3771
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         3772 non-null   object
#  1   Artist       3772 non-null   object
#  2   Song Name    3771 non-null   object
#  3   Korean Name  2786 non-null   object
#  4   Director     627 non-null    object
#  5   Video        3772 non-null   object
#  6   Type         3772 non-null   object
#  7   Release      3759 non-null   object
# dtypes: object(8)
# memory usage: 235.9+ KB

# %% [markdown]
# Podemos ver que el dataset contiene 3772 registros y 8 columnas.
# Como en los datasets anteriores, no nos vamos a quedar con todas las columnas, solo con las siguientes:
# - 'Date' es la fecha en la que salió la canción. Esta columna la cambiaremos de formato porque la queremos en formato fecha.
# Además, crearemos una nueva columna 'Year' con el año de lanzamiento de las canciones.
# - 'Artist' que es el nombre del artista de la canción.
# - 'Song Name' y 'Korean Name' que es el nombre de la canción.
# - 'Video' es el enlace al video de youtube.
# - 'Type' que es el tipo de artista.
#
# Esto significa que las columnas 'Director' y 'Release' las vamos a eliminar porque no son relevantes para nuestro análisis.

# %%
df4['Date'] = pd.to_datetime(df4['Date'], errors='coerce')
df4['Year'] = df4['Date'].dt.year
df4=df4.drop(['Director','Release'],axis=1)
df4
# Out:
#            Date              Artist                      Song Name  \
# 0    2020-05-22             Agust D                      Daechwita
# 1    2020-05-21               Yubin                 yaya (Me Time)
# 2    2020-05-21           OnlyOneOf             Angel (prod. GRAY)
# 3    2020-05-20         Ryu Sujeong                     Tiger Eyes
# 4    2020-05-20               Crush  Mayday feat. Joy (Red Velvet)
# ...         ...                 ...                            ...
# 3767 1994-08-08  Seo Taiji and Boys                       Eternity
# 3768 1993-06-06  Seo Taiji and Boys                    Anyhow Song
# 3769 1993-06-06  Seo Taiji and Boys                         To You
# 3770 1992-03-23  Seo Taiji and Boys                         I Know
# 3771 1992-03-23  Seo Taiji and Boys            You, In The Fantasy
#
#      Korean Name                         Video       Type  Year
# 0            대취타  https://youtu.be/qGjAWJ2zWWI   Boy Solo  2020
# 1             넵넵  https://youtu.be/BJD0arHF_5c  Girl Solo  2020
# 2            NaN  https://youtu.be/vVTo8p72FxQ        Boy  2020
# 3            NaN  https://youtu.be/aE6curPGQRY  Girl Solo  2020
# 4           자나깨나  https://youtu.be/29ycT6fA-Rs   Boy Solo  2020
# ...          ...                           ...        ...   ...
# 3767          영원  https://youtu.be/74usU0gB7r0        Boy  1994
# 3768         하여가  https://youtu.be/L-AxO7EPU8c        Boy  1993
# 3769         너에게  https://youtu.be/cxIAiAUyvXo        Boy  1993
# 3770       난 알아요  https://youtu.be/OEDHEzs5kyk        Boy  1992
# 3771     환상속의 그대  https://youtu.be/KGcwGoXfUDk        Boy  1992
#
# [3772 rows x 7 columns]

# %% [markdown]
# Para hacernos una idea de como están distribuidas las canciones del dataset a lo largo del tiempo vamos a realizar un histograma de los años.

# %%
fig6=px.histogram(df4, x='Year',
            title='Entre cuantos años tenemos datos?',
            color_discrete_sequence=px.colors.qualitative.Bold,
            template='plotly_white')

fig6.update_layout(
    font = {
        'family':"Times New Roman",
        'size':16,
        'color':'black'
        },
    title={
        'y':0.95,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top',
        'font_family':"Times New Roman",
        'font_size':25,
        'font_color':'black'},
    showlegend=True,
    bargap=0.01)

fig6.update_yaxes(
        title_font = {'size':20, 'color':'black'}, # Customización Elementos del Título.
        ticks="outside", tickwidth=2, tickcolor='black', ticklen=5, # Customización de los Ticks.
        showline=True, linewidth=2, linecolor='black', # Customizacion Axis Line (lineas de ejes)
        showgrid=True, gridwidth=0.1, gridcolor='grey', griddash='dash', minor_griddash=None, # Customización del GRID
        zeroline=False, zerolinewidth=2, zerolinecolor='black', # Customizando 0.
        range=[None, None]
        )

fig6.update_xaxes(
        title_font = {'size':20, 'color':'black'}, # Customización Elementos del Título.
        ticks="outside", tickwidth=2, tickcolor='black', ticklen=10, # Customización de los Ticks.
        showline=True, linewidth=2, linecolor='black', # Customizacion Axis Line (lineas de ejes)
        showgrid=True, gridwidth=0.1, gridcolor='grey', griddash='dash', minor_griddash="dot",  # Customización del GRID
        zeroline=False, zerolinewidth=2, zerolinecolor='black', # Customizando 0.
        range=[None, None]
        )
fig6.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="612a4100-d570-45eb-ab0c-eb65b85161ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("612a4100-d570-45eb-ab0c-eb65b85161ae")) {                    Plotly.newPlot(                        "612a4100-d570-45eb-ab0c-eb65b85161ae",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Year=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"rgb(127, 60, 141)","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2 ...

# %% [markdown]
# Podemos ver en el histograma que los datos van desde el año 1992 hasta el 2020. Además, podemos ver como cuanto más antiguo, menos videos tenemos, por lo que el groso de los registros son entre los 2010 más o menos y la actualidad.

# %% [markdown]
# Vamos a obtener los nombres de los artistas únicos que aparecen en el dataset, para tener una idea más general de los datos que tenemos.

# %%
artists=list(df4['Artist'].dropna().unique())
print(f'Número de artistas únicos: ',len(artists))
# Out:
# Número de artistas únicos:  856

# %% [markdown]
# Si recordamos, anteriormente, en el primer dataset, hemos sacado una lista de 254 grupos favoritos entre los fans, ahora podemos preguntarnos, cuántos de estos 856 artistas aparecen entre nuestras bandas favoritas?

# %%
artists_en_grupos=[]
artists_no_grupos=[]
for i in artists:
  if i in grupos:
    artists_en_grupos.append(i)
  else:
    artists_no_grupos.append(i)
print(f'Artistas entre los favoritos: ',len(artists_en_grupos))
print(f'Artistas entre los no favoritos: ',len(artists_no_grupos))
# Out:
# Artistas entre los favoritos:  186
# Artistas entre los no favoritos:  670

# %% [markdown]
# Observamos que entre los 856, solo 186 grupos aparecen entre los favoritos.
#
# Anteriormente hemos sacado dos listas. Una de bandas en activo y con club de fans maculinas y otra de bandas femeninas. A continuación vamos a juntarlas en una sola para obtener un listado de todas las bandas.

# %%
grupos_cf=favoritos_m_cf+favoritos_h_cf
print(f'Número de bandas totales: ',len(grupos_cf))
# Out:
# Número de bandas totales:  51

# %% [markdown]
# Entre estas 51 bandas favoritas, en activo y con club de fans, vamos a ver cuantas aparecen entre los artistas favoritos anteriores que han sacado canciones.

# %%
aux=[]
for i in grupos_cf:
  if i in artists_en_grupos:
    aux.append(i)
print(f'Número de bandas favoritas que aparecen en el dataset de las canciones: ',len(aux))
# Out:
# Número de bandas favoritas que aparecen en el dataset de las canciones:  47

# %% [markdown]
# Observamos que hemos reducido la lista a únicamente 47 bandas.

# %% [markdown]
# Vamos a analizar ahora las canciones.
#
# De los 47 grupos anteriores vamos a sacar algunos datos.

# %%
df4_artistas=df4[df4['Artist'].isin(aux)]
df4_artistas
# Out:
#            Date            Artist          Song Name Korean Name  \
# 8    2020-05-18          N.Flying            Amnesia         NaN
# 11   2020-05-15        Oh My Girl            Dolphin         NaN
# 13   2020-05-13           Busters            Paeonia        피오니아
# 17   2020-05-11            NU'EST     I'm In Trouble         NaN
# 24   2020-05-04             ASTRO              Knock       널 찾아가
# ...         ...               ...                ...         ...
# 3672 2006-03-09  Brown Eyed Girls        Come Closer        다가와서
# 3673 2006-02-24      Super Junior            Miracle         미라클
# 3676 2005-11-21           BIGBANG     Forever With U     포에버 윗 유
# 3677 2005-11-21           BIGBANG       Goodbye Baby     굿바이 베이비
# 3678 2005-11-11      Super Junior  Twins (Knock Out)         트윈스
#
#                              Video  Type  Year
# 8     https://youtu.be/UcxNeKzdDN4   Boy  2020
# 11    https://youtu.be/oaRTMjLdiDw  Girl  2020
# 13    https://youtu.be/ocFqqAMooSk  Girl  2020
# 17    https://youtu.be/4Lm9u-iXrDc   Boy  2020
# 24    https://youtu.be/Zz7YZtpz2Ek   Boy  2020
# ...                            ...   ...   ...
# 3672  https://youtu.be/W__OBj1Suwc  Girl  2006
# 3673  https://youtu.be/JDgtTGcEJtE   Boy  2006
# 3676  https://youtu.be/GYCD2KUB3WQ   Boy  2005
# 3677  https://youtu.be/smKuwvakHd0   Boy  2005
# 3678  https://youtu.be/SrazFGFRnhM   Boy  2005
#
# [844 rows x 7 columns]

# %%
fig7=px.histogram(df4_artistas, x='Type',
            color='Type',
            title='Tipo de bandas',
            color_discrete_sequence=px.colors.qualitative.Bold,
            template='plotly_white')

fig7.update_layout(
    font = {
        'family':"Times New Roman",
        'size':16,
        'color':'black'
        },
    title={
        'y':0.95,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top',
        'font_family':"Times New Roman",
        'font_size':25,
        'font_color':'black'},
    showlegend=True,
    bargap=0.01)

fig7.update_yaxes(
        title_font = {'size':20, 'color':'black'}, # Customización Elementos del Título.
        ticks="outside", tickwidth=2, tickcolor='black', ticklen=5, # Customización de los Ticks.
        showline=True, linewidth=2, linecolor='black', # Customizacion Axis Line (lineas de ejes)
        showgrid=True, gridwidth=0.1, gridcolor='grey', griddash='dash', minor_griddash=None, # Customización del GRID
        zeroline=False, zerolinewidth=2, zerolinecolor='black', # Customizando 0.
        range=[None, None]
        )

fig7.update_xaxes(
        title_font = {'size':20, 'color':'black'}, # Customización Elementos del Título.
        ticks="outside", tickwidth=2, tickcolor='black', ticklen=10, # Customización de los Ticks.
        showline=True, linewidth=2, linecolor='black', # Customizacion Axis Line (lineas de ejes)
        showgrid=True, gridwidth=0.1, gridcolor='grey', griddash='dash', minor_griddash="dot",  # Customización del GRID
        zeroline=False, zerolinewidth=2, zerolinecolor='black', # Customizando 0.
        range=[None, None]
        )
fig7.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2b586035-e801-4072-8294-0e12d0737af2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b586035-e801-4072-8294-0e12d0737af2")) {                    Plotly.newPlot(                        "2b586035-e801-4072-8294-0e12d0737af2",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Type=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Boy","marker":{"color":"rgb(127, 60, 141)","pattern":{"shape":""}},"name":"Boy","offsetgroup":"Boy","orientation":"v","showlegend":true,"x":["Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy","Boy ...

# %% [markdown]
# Observando este gráfico podemos afirmar casi con certeza que en nuestro festival vamos a contar con más bandas masculinas que femeninas, ya que en el dataset contamos con 673 videos de canciones de hombres y con 171 de mujeres.

# %% [markdown]
# Vamos a ver ahora qué bandas tienen más videos en la base de datos.

# %%
fig8=px.histogram(df4_artistas, x='Artist',
            color='Artist',
            title='Quién tiene más videos?',
            color_discrete_sequence=px.colors.qualitative.Bold,
            template='plotly_white')

fig8.update_layout(
    font = {
        'family':"Times New Roman",
        'size':16,
        'color':'black'
        },
    title={
        'y':0.95,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top',
        'font_family':"Times New Roman",
        'font_size':25,
        'font_color':'black'},
    showlegend=True,
    bargap=0.01)

fig8.update_yaxes(
        title_font = {'size':20, 'color':'black'}, # Customización Elementos del Título.
        ticks="outside", tickwidth=2, tickcolor='black', ticklen=5, # Customización de los Ticks.
        showline=True, linewidth=2, linecolor='black', # Customizacion Axis Line (lineas de ejes)
        showgrid=True, gridwidth=0.1, gridcolor='grey', griddash='dash', minor_griddash=None, # Customización del GRID
        zeroline=False, zerolinewidth=2, zerolinecolor='black', # Customizando 0.
        range=[None, None]
        )

fig8.update_xaxes(
        title_font = {'size':20, 'color':'black'}, # Customización Elementos del Título.
        ticks="outside", tickwidth=2, tickcolor='black', ticklen=10, # Customización de los Ticks.
        showline=True, linewidth=2, linecolor='black', # Customizacion Axis Line (lineas de ejes)
        showgrid=True, gridwidth=0.1, gridcolor='grey', griddash='dash', minor_griddash="dot",  # Customización del GRID
        zeroline=False, zerolinewidth=2, zerolinecolor='black', # Customizando 0.
        range=[None, None]
        )
fig8.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="66ee1dfe-183a-440d-b716-c4ef11e1aa86" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("66ee1dfe-183a-440d-b716-c4ef11e1aa86")) {                    Plotly.newPlot(                        "66ee1dfe-183a-440d-b716-c4ef11e1aa86",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Artist=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"N.Flying","marker":{"color":"rgb(127, 60, 141)","pattern":{"shape":""}},"name":"N.Flying","offsetgroup":"N.Flying","orientation":"v","showlegend":true,"x":["N.Flying","N.Flying","N.Flying","N.Flying","N.Flying","N.Flying","N.Flying","N.Flying","N.Flying","N.Flying","N.Flying","N.Flying","N.Flying","N.Flying","N.Flying","N.Flying","N.Flying","N.Flying","N.Flying"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Artist=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oh My Girl","marker":{"color":"rgb(17, 165, 121)","pattern":{"shape":""}},"name":"Oh My Girl","offsetgroup":"Oh My Girl","orientation":"v","showlegend":true,"x":["Oh My Girl","Oh My Girl","Oh My Girl","Oh My Girl","Oh My Girl","Oh My Girl","Oh My Girl","Oh My Girl","Oh My Girl","Oh My Girl","Oh My Girl","Oh My Girl","Oh My Girl","Oh My Girl","Oh My Girl"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Artist=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Busters","marker":{"color":"rgb(57, 105, 172)","pattern":{"shape":""}},"name":"Busters","offsetgroup":"Busters","orientation":"v","showlegend":true,"x":["Busters","Busters","Busters","Busters","Busters"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Artist=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NU'EST","marker":{"color":"rgb(242, 183, 1)","pattern":{"shape":""}},"name":"NU'EST","offsetgroup":"NU'EST","orientation":"v","showlegend":true,"x":["NU'EST","NU'EST","NU'EST","NU'EST","NU'EST","NU'EST","NU'EST","NU'EST","NU'EST","NU'EST","NU'EST","NU'EST","NU'EST","NU'EST","NU'EST","NU'EST","NU'EST","NU'EST"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Artist=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ASTRO","marker":{"color":"rgb(231, 63, 116)","pattern":{"shape":""}},"name":"ASTRO","offsetgroup":"ASTRO","orientation":"v","showlegend":true,"x":["ASTRO","ASTRO","ASTRO","ASTRO","ASTRO","ASTRO","ASTRO","ASTRO"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Artist=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GWSN","marker":{"color":"rgb(128, 186, 90)","pattern":{"shape":""}},"name":"GWSN","offsetgroup":"GWSN","orientation":"v","showlegend":true,"x":["GWSN","GWSN","GWSN","GWSN","GWSN","GWSN"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Artist=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GOT7","marker":{"color":"rgb(230, 131, 16)","pattern":{"shape":""}},"name":"GOT7","offsetgroup":"GOT7","orientation":"v","showlegend":true,"x":["GOT7","GOT7","GOT7","GOT7","GOT7","GOT7","GOT7","GOT7","GOT7","GOT7","GOT7","GOT7","GOT7","GOT7","GOT7","GOT7","GOT7","GOT7","GOT7","GOT7","GOT7","GOT7","GOT7","GOT7","GOT7"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Artist=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra ...

# %% [markdown]
# Podemos ver como entre estas 47 bandas, la que menos videos tiene cuenta con 3 videos y la que más con 57, esto puede ser por muchas razones, como por ejemplo que la banda con los 3 videos sea más antigua y que la mayoría de canciones no estén subidas a la plataforma, por lo que no vamos a tener en cuenta este dato para elegir nuestras 10 bandas finales.

# %% [markdown]
# A continuación vamos a encaminarnos a nuestra base de datos final con la elección de los grupos.
# Para ello vamos a hacer un nuevo dataframe que contenga los grupos con club de fans y en activo. Anteriormente hemos decidido que la cantidad de videos en youtube podía estar sesgada por el año de debut de los grurpos, por lo que vamos a utlizar la base de datos de 51 grupos en vez de la de 47.

# %%
todos_artistas=df2[df2['Name'].isin(grupos_cf)]
todos_artistas_1=df3[df3['Name'].isin(grupos_cf)]
todos_artistas=pd.concat([todos_artistas,todos_artistas_1])
todos_artistas
# Out:
#                  Name Korean Name      Debut    Company  Members Fanclub Name  \
# 0                100%        백퍼센트 2012-09-18  TOP Media        4   Perfection
# 3                 24K        투포케이 2012-09-06     Choeun        8          24U
# 5                 2PM         투피엠 2008-07-04        JYP        6      Hottest
# 8               A.C.E         에이스 2017-05-23       Beat        5       Choice
# 11              AB6IX       에이비식스 2019-05-22  Brand New        5        ABNEW
# 13              ASTRO        아스트로 2016-02-23   Fantagio        6        AROHA
# 18               B1A4       비원에이포 2010-04-19         WM        5         BANA
# 21            BIGBANG          빅뱅 2006-08-19         YG        4          VIP
# 27            Block B         블락비 2011-04-13         KQ        7          BBC
# 30               BtoB         비투비 2012-03-21       Cube        7       Melody
# 31                BTS       방탄소년단 2013-06-13    Big Hit        7         ARMY
# 35             CNBLUE        씨엔블루 2010-01-14        FNC        4        Boice
# 37         CROSS GENE        크로스진 2012-07-08      Amuse        5   Chromosome
# 43                EXO          엑소 2012-04-08         SM        9        EXO-L
# 45           FTISLAND    에프티 아일랜드 2007-06-07        FNC        4   Primadonna
# 48               GOT7         갓세븐 2014-01-16        JYP        7       I GOT7
# 54          Highlight       하이라이트 2009-10-14  Around Us        4        B2uty
# 59               iKON         아이콘 2015-09-15         YG        6       iKONIC
# 62           Infinite        인피니트 2010-06-09    Woollim        6     Inspirit
# 68                JYJ      제이와이제이 2010-09-08      C-JeS        3   Cassiopeia
# 70                KNK         크나큰 2016-03-03        YNB        5  Tinker Bell
# 79              MBLAQ         엠블랙 2009-10-14    J. Tune        3           A+
# 81           MONSTA X       몬스타엑스 2014-05-14   Starship        6      Monbebe
# 86             MYNAME        마이네임 2011-10-27         H2        5       MYgirl
# 90           N.Flying        엔플라잉 2015-05-20        FNC        4        N.Fia
# 91                NCT         엔시티 2016-04-09         SM       18       NCTzen
# 95             NU'EST        뉴이스트 2012-03-15     Pledis        5         LOΛΕ
# 105         Seventeen         세븐틴 2015-05-26     Pledis       13        Carat
# 106               SF9      에스에프나인 2016-10-05        FNC        9      Fantasy
# 108            SHINee         샤이니 2008-05-22         SM        4       Shawol
# 116      Super Junior       슈퍼주니어 2005-11-06         SM       11          ELF
# 119          Teen Top          틴탑 2010-07-09  TOP Media        5        Angel
# 131            U-KISS         유키스 2008-08-28   NH Media        6       Kissme
# 133              UNIQ         유니크 2014-10-20     Yuehua        5      Unicorn
# 134          UP10TION         업텐션 2015-09-11  TOP Media       10      HONEY10
# 139            VICTON          빅톤 2016-11-09     Plan A        7        Alice
# 140              VIXX          빅스 2012-05-24  Jellyfish        6    Starlight
# 145            WINNER          위너 2014-08-12         YG        4          Ace
# 14              Apink        에이핑크 2011-04-19     Plan A        6   Pink Panda
# 29   Brown Eyed Girls  브라운 아이드 걸스 2006-03-02     Mystic        4  Everlasting
# 31            Busters        버스터즈 2017-11-27        JTG        5       Bu-Chu
# 39                CLC         씨엘씨 2015-03-18       Cube        7      Chesire
# 47                DIA         다이아 2015-07-14        MBK        7          AID
# 55               EXID      이엑스아이디 2012-02-16     Yedang        5         LEGO
# 65            Gfriend        여자친구 2015-01-15     Source        6        Buddy
# 77               GWSN        공원소녀 2018-09-05   Kiwi Pop        7         Groo
# 89               ITZY          있지 2019-02-12        JYP        5        Mitzy
# 99            Lovelyz        러블리즈 2014-11-17    Woollim        8    Lovelinus
# 101           Mamamoo         마마무 2014-06-18        RBW        4       Moomoo
# 112        Oh My Girl        오마이걸 2015-04-21         WM        7      Miracle
# 132           Sonamoo         소나무 2014-12-29         TS        5    Solbangul
#
#     Active
# 0      Yes
# 3      Yes
# 5      Yes
# 8      Yes
# 11     Yes
# 13     Yes
# 18     Yes
# 21     Yes
# 27     Yes
# 30     Yes
# 31     Yes
# 35     Yes
# 37     Yes
# 43     Yes
# 45     Yes
# 48     Yes
# 54     Yes
# 59     Yes
# 62     Yes
# 68     Yes
# 70     Yes
# 79     Yes
# 81     Yes
# 86     Yes
# 90     Yes
# 91     Yes
# 95     Yes
# 105    Yes
# 106    Yes
# 108    Yes
# 116    Yes
# 119    Yes
# 131    Yes
# 133    Yes
# 134    Yes
# 139    Yes
# 140    Yes
# 145    Yes
# 14     Yes
# 29     Yes
# 31     Yes
# 39     Yes
# 47     Yes
# 55     Yes
# 65     Yes
# 77     Yes
# 89     Yes
# 99     Yes
# 101    Yes
# 112    Yes
# 132    Yes

# %% [markdown]
# En este dataframe obtenemos los 51 grupos con el día de debut, la productora, los miembros que tiene cada banda, el nombre del club de fans y, como ya sabíamos, la columna de si la banda sigue en activo, con todos los registros es sí, por lo que esta columna la podemos eliminar.
#
# Además, vamos a añadir una columna que nos diga si el grupo es femenino o masculino.

# %%
# Función para clasificar los grupos
def clasificar_grupo(artista, lista_masculinos):
    if artista in lista_masculinos:
        return 'Boy'
    else:
        return 'Girl'

todos_artistas['Gender'] = todos_artistas['Name'].apply(clasificar_grupo, args=(favoritos_h_cf,))
todos_artistas=todos_artistas.drop(['Active'], axis=1)
todos_artistas
# Out:
#                  Name Korean Name      Debut    Company  Members Fanclub Name  \
# 0                100%        백퍼센트 2012-09-18  TOP Media        4   Perfection
# 3                 24K        투포케이 2012-09-06     Choeun        8          24U
# 5                 2PM         투피엠 2008-07-04        JYP        6      Hottest
# 8               A.C.E         에이스 2017-05-23       Beat        5       Choice
# 11              AB6IX       에이비식스 2019-05-22  Brand New        5        ABNEW
# 13              ASTRO        아스트로 2016-02-23   Fantagio        6        AROHA
# 18               B1A4       비원에이포 2010-04-19         WM        5         BANA
# 21            BIGBANG          빅뱅 2006-08-19         YG        4          VIP
# 27            Block B         블락비 2011-04-13         KQ        7          BBC
# 30               BtoB         비투비 2012-03-21       Cube        7       Melody
# 31                BTS       방탄소년단 2013-06-13    Big Hit        7         ARMY
# 35             CNBLUE        씨엔블루 2010-01-14        FNC        4        Boice
# 37         CROSS GENE        크로스진 2012-07-08      Amuse        5   Chromosome
# 43                EXO          엑소 2012-04-08         SM        9        EXO-L
# 45           FTISLAND    에프티 아일랜드 2007-06-07        FNC        4   Primadonna
# 48               GOT7         갓세븐 2014-01-16        JYP        7       I GOT7
# 54          Highlight       하이라이트 2009-10-14  Around Us        4        B2uty
# 59               iKON         아이콘 2015-09-15         YG        6       iKONIC
# 62           Infinite        인피니트 2010-06-09    Woollim        6     Inspirit
# 68                JYJ      제이와이제이 2010-09-08      C-JeS        3   Cassiopeia
# 70                KNK         크나큰 2016-03-03        YNB        5  Tinker Bell
# 79              MBLAQ         엠블랙 2009-10-14    J. Tune        3           A+
# 81           MONSTA X       몬스타엑스 2014-05-14   Starship        6      Monbebe
# 86             MYNAME        마이네임 2011-10-27         H2        5       MYgirl
# 90           N.Flying        엔플라잉 2015-05-20        FNC        4        N.Fia
# 91                NCT         엔시티 2016-04-09         SM       18       NCTzen
# 95             NU'EST        뉴이스트 2012-03-15     Pledis        5         LOΛΕ
# 105         Seventeen         세븐틴 2015-05-26     Pledis       13        Carat
# 106               SF9      에스에프나인 2016-10-05        FNC        9      Fantasy
# 108            SHINee         샤이니 2008-05-22         SM        4       Shawol
# 116      Super Junior       슈퍼주니어 2005-11-06         SM       11          ELF
# 119          Teen Top          틴탑 2010-07-09  TOP Media        5        Angel
# 131            U-KISS         유키스 2008-08-28   NH Media        6       Kissme
# 133              UNIQ         유니크 2014-10-20     Yuehua        5      Unicorn
# 134          UP10TION         업텐션 2015-09-11  TOP Media       10      HONEY10
# 139            VICTON          빅톤 2016-11-09     Plan A        7        Alice
# 140              VIXX          빅스 2012-05-24  Jellyfish        6    Starlight
# 145            WINNER          위너 2014-08-12         YG        4          Ace
# 14              Apink        에이핑크 2011-04-19     Plan A        6   Pink Panda
# 29   Brown Eyed Girls  브라운 아이드 걸스 2006-03-02     Mystic        4  Everlasting
# 31            Busters        버스터즈 2017-11-27        JTG        5       Bu-Chu
# 39                CLC         씨엘씨 2015-03-18       Cube        7      Chesire
# 47                DIA         다이아 2015-07-14        MBK        7          AID
# 55               EXID      이엑스아이디 2012-02-16     Yedang        5         LEGO
# 65            Gfriend        여자친구 2015-01-15     Source        6        Buddy
# 77               GWSN        공원소녀 2018-09-05   Kiwi Pop        7         Groo
# 89               ITZY          있지 2019-02-12        JYP        5        Mitzy
# 99            Lovelyz        러블리즈 2014-11-17    Woollim        8    Lovelinus
# 101           Mamamoo         마마무 2014-06-18        RBW        4       Moomoo
# 112        Oh My Girl        오마이걸 2015-04-21         WM        7      Miracle
# 132           Sonamoo         소나무 2014-12-29         TS        5    Solbangul
#
#     Gender
# 0      Boy
# 3      Boy
# 5      Boy
# 8      Boy
# 11     Boy
# 13     Boy
# 18     Boy
# 21     Boy
# 27     Boy
# 30     Boy
# 31     Boy
# 35     Boy
# 37     Boy
# 43     Boy
# 45     Boy
# 48     Boy
# 54     Boy
# 59     Boy
# 62     Boy
# 68     Boy
# 70     Boy
# 79     Boy
# 81     Boy
# 86     Boy
# 90     Boy
# 91     Boy
# 95     Boy
# 105    Boy
# 106    Boy
# 108    Boy
# 116    Boy
# 119    Boy
# 131    Boy
# 133    Boy
# 134    Boy
# 139    Boy
# 140    Boy
# 145    Boy
# 14    Girl
# 29    Girl
# 31    Girl
# 39    Girl
# 47    Girl
# 55    Girl
# 65    Girl
# 77    Girl
# 89    Girl
# 99    Girl
# 101   Girl
# 112   Girl
# 132   Girl

# %%
todos_artistas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, 0 to 132
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          51 non-null     object
#  1   Korean Name   51 non-null     object
#  2   Debut         51 non-null     datetime64[ns]
#  3   Company       51 non-null     object
#  4   Members       51 non-null     int64
#  5   Fanclub Name  51 non-null     object
#  6   Gender        51 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 3.2+ KB

# %% [markdown]
# Como anteriormente en este tipo de dataframes, vamos a sacar el año de debut de los grupos.

# %%
todos_artistas['Year'] = todos_artistas['Debut'].dt.year
todos_artistas
# Out:
#                  Name Korean Name      Debut    Company  Members Fanclub Name  \
# 0                100%        백퍼센트 2012-09-18  TOP Media        4   Perfection
# 3                 24K        투포케이 2012-09-06     Choeun        8          24U
# 5                 2PM         투피엠 2008-07-04        JYP        6      Hottest
# 8               A.C.E         에이스 2017-05-23       Beat        5       Choice
# 11              AB6IX       에이비식스 2019-05-22  Brand New        5        ABNEW
# 13              ASTRO        아스트로 2016-02-23   Fantagio        6        AROHA
# 18               B1A4       비원에이포 2010-04-19         WM        5         BANA
# 21            BIGBANG          빅뱅 2006-08-19         YG        4          VIP
# 27            Block B         블락비 2011-04-13         KQ        7          BBC
# 30               BtoB         비투비 2012-03-21       Cube        7       Melody
# 31                BTS       방탄소년단 2013-06-13    Big Hit        7         ARMY
# 35             CNBLUE        씨엔블루 2010-01-14        FNC        4        Boice
# 37         CROSS GENE        크로스진 2012-07-08      Amuse        5   Chromosome
# 43                EXO          엑소 2012-04-08         SM        9        EXO-L
# 45           FTISLAND    에프티 아일랜드 2007-06-07        FNC        4   Primadonna
# 48               GOT7         갓세븐 2014-01-16        JYP        7       I GOT7
# 54          Highlight       하이라이트 2009-10-14  Around Us        4        B2uty
# 59               iKON         아이콘 2015-09-15         YG        6       iKONIC
# 62           Infinite        인피니트 2010-06-09    Woollim        6     Inspirit
# 68                JYJ      제이와이제이 2010-09-08      C-JeS        3   Cassiopeia
# 70                KNK         크나큰 2016-03-03        YNB        5  Tinker Bell
# 79              MBLAQ         엠블랙 2009-10-14    J. Tune        3           A+
# 81           MONSTA X       몬스타엑스 2014-05-14   Starship        6      Monbebe
# 86             MYNAME        마이네임 2011-10-27         H2        5       MYgirl
# 90           N.Flying        엔플라잉 2015-05-20        FNC        4        N.Fia
# 91                NCT         엔시티 2016-04-09         SM       18       NCTzen
# 95             NU'EST        뉴이스트 2012-03-15     Pledis        5         LOΛΕ
# 105         Seventeen         세븐틴 2015-05-26     Pledis       13        Carat
# 106               SF9      에스에프나인 2016-10-05        FNC        9      Fantasy
# 108            SHINee         샤이니 2008-05-22         SM        4       Shawol
# 116      Super Junior       슈퍼주니어 2005-11-06         SM       11          ELF
# 119          Teen Top          틴탑 2010-07-09  TOP Media        5        Angel
# 131            U-KISS         유키스 2008-08-28   NH Media        6       Kissme
# 133              UNIQ         유니크 2014-10-20     Yuehua        5      Unicorn
# 134          UP10TION         업텐션 2015-09-11  TOP Media       10      HONEY10
# 139            VICTON          빅톤 2016-11-09     Plan A        7        Alice
# 140              VIXX          빅스 2012-05-24  Jellyfish        6    Starlight
# 145            WINNER          위너 2014-08-12         YG        4          Ace
# 14              Apink        에이핑크 2011-04-19     Plan A        6   Pink Panda
# 29   Brown Eyed Girls  브라운 아이드 걸스 2006-03-02     Mystic        4  Everlasting
# 31            Busters        버스터즈 2017-11-27        JTG        5       Bu-Chu
# 39                CLC         씨엘씨 2015-03-18       Cube        7      Chesire
# 47                DIA         다이아 2015-07-14        MBK        7          AID
# 55               EXID      이엑스아이디 2012-02-16     Yedang        5         LEGO
# 65            Gfriend        여자친구 2015-01-15     Source        6        Buddy
# 77               GWSN        공원소녀 2018-09-05   Kiwi Pop        7         Groo
# 89               ITZY          있지 2019-02-12        JYP        5        Mitzy
# 99            Lovelyz        러블리즈 2014-11-17    Woollim        8    Lovelinus
# 101           Mamamoo         마마무 2014-06-18        RBW        4       Moomoo
# 112        Oh My Girl        오마이걸 2015-04-21         WM        7      Miracle
# 132           Sonamoo         소나무 2014-12-29         TS        5    Solbangul
#
#     Gender  Year
# 0      Boy  2012
# 3      Boy  2012
# 5      Boy  2008
# 8      Boy  2017
# 11     Boy  2019
# 13     Boy  2016
# 18     Boy  2010
# 21     Boy  2006
# 27     Boy  2011
# 30     Boy  2012
# 31     Boy  2013
# 35     Boy  2010
# 37     Boy  2012
# 43     Boy  2012
# 45     Boy  2007
# 48     Boy  2014
# 54     Boy  2009
# 59     Boy  2015
# 62     Boy  2010
# 68     Boy  2010
# 70     Boy  2016
# 79     Boy  2009
# 81     Boy  2014
# 86     Boy  2011
# 90     Boy  2015
# 91     Boy  2016
# 95     Boy  2012
# 105    Boy  2015
# 106    Boy  2016
# 108    Boy  2008
# 116    Boy  2005
# 119    Boy  2010
# 131    Boy  2008
# 133    Boy  2014
# 134    Boy  2015
# 139    Boy  2016
# 140    Boy  2012
# 145    Boy  2014
# 14    Girl  2011
# 29    Girl  2006
# 31    Girl  2017
# 39    Girl  2015
# 47    Girl  2015
# 55    Girl  2012
# 65    Girl  2015
# 77    Girl  2018
# 89    Girl  2019
# 99    Girl  2014
# 101   Girl  2014
# 112   Girl  2015
# 132   Girl  2014

# %%
todos_artistas=todos_artistas.sort_values(by='Year', ascending=False)
todos_artistas
# Out:
#                  Name Korean Name      Debut    Company  Members Fanclub Name  \
# 11              AB6IX       에이비식스 2019-05-22  Brand New        5        ABNEW
# 89               ITZY          있지 2019-02-12        JYP        5        Mitzy
# 77               GWSN        공원소녀 2018-09-05   Kiwi Pop        7         Groo
# 31            Busters        버스터즈 2017-11-27        JTG        5       Bu-Chu
# 8               A.C.E         에이스 2017-05-23       Beat        5       Choice
# 91                NCT         엔시티 2016-04-09         SM       18       NCTzen
# 70                KNK         크나큰 2016-03-03        YNB        5  Tinker Bell
# 13              ASTRO        아스트로 2016-02-23   Fantagio        6        AROHA
# 106               SF9      에스에프나인 2016-10-05        FNC        9      Fantasy
# 139            VICTON          빅톤 2016-11-09     Plan A        7        Alice
# 59               iKON         아이콘 2015-09-15         YG        6       iKONIC
# 134          UP10TION         업텐션 2015-09-11  TOP Media       10      HONEY10
# 47                DIA         다이아 2015-07-14        MBK        7          AID
# 39                CLC         씨엘씨 2015-03-18       Cube        7      Chesire
# 90           N.Flying        엔플라잉 2015-05-20        FNC        4        N.Fia
# 65            Gfriend        여자친구 2015-01-15     Source        6        Buddy
# 112        Oh My Girl        오마이걸 2015-04-21         WM        7      Miracle
# 105         Seventeen         세븐틴 2015-05-26     Pledis       13        Carat
# 145            WINNER          위너 2014-08-12         YG        4          Ace
# 99            Lovelyz        러블리즈 2014-11-17    Woollim        8    Lovelinus
# 133              UNIQ         유니크 2014-10-20     Yuehua        5      Unicorn
# 101           Mamamoo         마마무 2014-06-18        RBW        4       Moomoo
# 132           Sonamoo         소나무 2014-12-29         TS        5    Solbangul
# 81           MONSTA X       몬스타엑스 2014-05-14   Starship        6      Monbebe
# 48               GOT7         갓세븐 2014-01-16        JYP        7       I GOT7
# 31                BTS       방탄소년단 2013-06-13    Big Hit        7         ARMY
# 0                100%        백퍼센트 2012-09-18  TOP Media        4   Perfection
# 140              VIXX          빅스 2012-05-24  Jellyfish        6    Starlight
# 3                 24K        투포케이 2012-09-06     Choeun        8          24U
# 95             NU'EST        뉴이스트 2012-03-15     Pledis        5         LOΛΕ
# 30               BtoB         비투비 2012-03-21       Cube        7       Melody
# 55               EXID      이엑스아이디 2012-02-16     Yedang        5         LEGO
# 37         CROSS GENE        크로스진 2012-07-08      Amuse        5   Chromosome
# 43                EXO          엑소 2012-04-08         SM        9        EXO-L
# 27            Block B         블락비 2011-04-13         KQ        7          BBC
# 14              Apink        에이핑크 2011-04-19     Plan A        6   Pink Panda
# 86             MYNAME        마이네임 2011-10-27         H2        5       MYgirl
# 62           Infinite        인피니트 2010-06-09    Woollim        6     Inspirit
# 119          Teen Top          틴탑 2010-07-09  TOP Media        5        Angel
# 35             CNBLUE        씨엔블루 2010-01-14        FNC        4        Boice
# 68                JYJ      제이와이제이 2010-09-08      C-JeS        3   Cassiopeia
# 18               B1A4       비원에이포 2010-04-19         WM        5         BANA
# 54          Highlight       하이라이트 2009-10-14  Around Us        4        B2uty
# 79              MBLAQ         엠블랙 2009-10-14    J. Tune        3           A+
# 131            U-KISS         유키스 2008-08-28   NH Media        6       Kissme
# 108            SHINee         샤이니 2008-05-22         SM        4       Shawol
# 5                 2PM         투피엠 2008-07-04        JYP        6      Hottest
# 45           FTISLAND    에프티 아일랜드 2007-06-07        FNC        4   Primadonna
# 29   Brown Eyed Girls  브라운 아이드 걸스 2006-03-02     Mystic        4  Everlasting
# 21            BIGBANG          빅뱅 2006-08-19         YG        4          VIP
# 116      Super Junior       슈퍼주니어 2005-11-06         SM       11          ELF
#
#     Gender  Year
# 11     Boy  2019
# 89    Girl  2019
# 77    Girl  2018
# 31    Girl  2017
# 8      Boy  2017
# 91     Boy  2016
# 70     Boy  2016
# 13     Boy  2016
# 106    Boy  2016
# 139    Boy  2016
# 59     Boy  2015
# 134    Boy  2015
# 47    Girl  2015
# 39    Girl  2015
# 90     Boy  2015
# 65    Girl  2015
# 112   Girl  2015
# 105    Boy  2015
# 145    Boy  2014
# 99    Girl  2014
# 133    Boy  2014
# 101   Girl  2014
# 132   Girl  2014
# 81     Boy  2014
# 48     Boy  2014
# 31     Boy  2013
# 0      Boy  2012
# 140    Boy  2012
# 3      Boy  2012
# 95     Boy  2012
# 30     Boy  2012
# 55    Girl  2012
# 37     Boy  2012
# 43     Boy  2012
# 27     Boy  2011
# 14    Girl  2011
# 86     Boy  2011
# 62     Boy  2010
# 119    Boy  2010
# 35     Boy  2010
# 68     Boy  2010
# 18     Boy  2010
# 54     Boy  2009
# 79     Boy  2009
# 131    Boy  2008
# 108    Boy  2008
# 5      Boy  2008
# 45     Boy  2007
# 29    Girl  2006
# 21     Boy  2006
# 116    Boy  2005

# %% [markdown]
# Los datos que tenemos en el proyecto van únicamente hasta el 2020, por lo que vamos a ampliar esta información hasta el 2024.
#
# Hemos buscado los grupos de k-pop más influyentes en los últimos 4 años. Esto es importante porque los grupos que han triunfado en los últimos años suele ser más probable que sigan triunfando en los años próximos.

# %% [markdown]
# Enlace página grupos k-pop 2024: https://routenote.com/es/blog/los-10-artistas-de-k-pop-mas-seguidos-en-spotify-en-2024/

# %%
grupos_2024=['BTS','BLACKPINK','TWICE','V','j-hope','RM','Stray Kids','Jung Kook','Agust D','SEVETEEN']

# %% [markdown]
# Enlace página grupos k-pop 2023: https://www.publimetro.com.mx/entretenimiento/2023/12/11/kpop-spotify-lo-mas-escuchado-de-2023-bts-blackpink-newjeans-artistas-y-grupos/

# %%
grupos_2023=['BTS','BLACKPINK','Jung Kook','NewJeans','Stray Kids','Jimin','TWICE','SEVENTEEN',
             'TXT','LE SSERAFIM','V','ENHYPEN','FIFTY FIFTY','(G)I-DALE','IVE',
             'Agust D','aespa','NCT DREAM','LISA','j-hope']

# %% [markdown]
# Enlace página grupos k-pop 2022: https://www.univision.com/musica/bts-ateez-txt-straykids-los-grupos-de-k-pop-que-rompieron-este-2022-y-no-pueden-faltar-en-tu-2023-playlist

# %%
grupos_2022=['BTS','STRAY KIDS','ATEEZ','DRIPPIN','BLACKPINK','BIGANG','TWICE','TXT','ITZY','ENHYPEN']

# %% [markdown]
# Enlace página grupos k-pop 2021: https://www.soundpark.news/noticias/Conoce-el-top-10-de-los-grupos-de-K-Pop-mas-influyentes-de-2021-en-el-mundo-20210706-0010.html

# %%
grupos_2021=['NCT','BTS','BAEKHYUN','EXO','SEVENTEEN','IU','Rosé','TXT','BLACKPINK','TWICE']

# %% [markdown]
# Una vez ya tenemos toda la información de los últimos 4 años en listas vamos a comprobar con cuanta frecuencia se repiten estos nombres.

# %%
conteo_grupos = {}
for grupo in grupos_2021:
    if grupo in conteo_grupos:
        conteo_grupos[grupo] += 1
    else:
        conteo_grupos[grupo] = 1

# %%
for grupo in grupos_2022:
    if grupo in conteo_grupos:
        conteo_grupos[grupo] += 1
    else:
        conteo_grupos[grupo] = 1

# %%
for grupo in grupos_2023:
    if grupo in conteo_grupos:
        conteo_grupos[grupo] += 1
    else:
        conteo_grupos[grupo] = 1

# %%
for grupo in grupos_2024:
    if grupo in conteo_grupos:
        conteo_grupos[grupo] += 1
    else:
        conteo_grupos[grupo] = 1

# %%
df_grupos_nuevos=pd.DataFrame(list(conteo_grupos.items()), columns=['Grupo', 'Frecuencia'])
df_grupos_nuevos=df_grupos_nuevos.sort_values(by='Frecuencia', ascending=False)
df_grupos_nuevos
# Out:
#           Grupo  Frecuencia
# 9         TWICE           4
# 1           BTS           4
# 8     BLACKPINK           4
# 7           TXT           3
# 21            V           2
# 15      ENHYPEN           2
# 25      Agust D           2
# 16    Jung Kook           2
# 4     SEVENTEEN           2
# 29       j-hope           2
# 18   Stray Kids           2
# 27    NCT DREAM           1
# 20  LE SSERAFIM           1
# 26        aespa           1
# 28         LISA           1
# 24          IVE           1
# 23    (G)I-DALE           1
# 22  FIFTY FIFTY           1
# 30           RM           1
# 0           NCT           1
# 19        Jimin           1
# 17     NewJeans           1
# 14         ITZY           1
# 13       BIGANG           1
# 12      DRIPPIN           1
# 11        ATEEZ           1
# 10   STRAY KIDS           1
# 6          Rosé           1
# 5            IU           1
# 3           EXO           1
# 2      BAEKHYUN           1
# 31     SEVETEEN           1

# %% [markdown]
# Podemos ver que, en los últimos 4 años, hay 3 gruoos que están presentes en todos estos años y 1 grupo que está presente en 3 de los últimos 4 años.
#
# Estos 4 grupos van a ser los primeros elegidos para nuestro festival.

# %%
df_grupos_nuevos=df_grupos_nuevos[:4]
df_grupos_nuevos
# Out:
#        Grupo  Frecuencia
# 9      TWICE           4
# 1        BTS           4
# 8  BLACKPINK           4
# 7        TXT           3

# %% [markdown]
# Como hemos dicho al principio, los clubs de fans son muy importantes.
# Un grupo con club de fans mueve a mucha más gente que uno sin, y nosotros queremos que a nuestro festival venga el máximo número de gente posible, por lo que vamos a analizar cuales son los Fandoms más potentes en el mundo del k-pop actualmente.

# %% [markdown]
# Enlace principales fandoms: https://es.quora.com/Aparte-de-Army-cu%C3%A1les-son-los-fandoms-m%C3%A1s-grande-dentro-del-K-pop

# %%
nombres_cf=['ARMY','BLINK','ONCE','STAY','NCTzen','EXO-L','MOA','CARAT']

# %% [markdown]
# Ahora vamos a ver cuales de estos fandoms aparecen en nuestro dataset.

# %%
nombres_fandoms=list(todos_artistas['Fanclub Name'])
nombres_fandoms
# Out:
# ['ABNEW',
#  'Mitzy',
#  'Groo',
#  'Bu-Chu',
#  'Choice',
#  'NCTzen',
#  'Tinker Bell',
#  'AROHA',
#  'Fantasy',
#  'Alice',
#  'iKONIC',
#  'HONEY10',
#  'AID',
#  'Chesire',
#  'N.Fia',
#  'Buddy',
#  'Miracle',
#  'Carat',
#  'Ace',
#  'Lovelinus',
#  'Unicorn',
#  'Moomoo',
#  'Solbangul',
#  'Monbebe',
#  'I GOT7',
#  'ARMY',
#  'Perfection',
#  'Starlight',
#  '24U',
#  'LOΛΕ',
#  'Melody',
#  'LEGO',
#  'Chromosome',
#  'EXO-L',
#  'BBC',
#  'Pink Panda',
#  'MYgirl',
#  'Inspirit',
#  'Angel',
#  'Boice',
#  'Cassiopeia',
#  'BANA',
#  'B2uty',
#  'A+',
#  'Kissme',
#  'Shawol',
#  'Hottest',
#  'Primadonna',
#  'Everlasting',
#  'VIP',
#  'ELF']

# %%
mejores_fandoms=[]
for i in nombres_fandoms:
  if i in nombres_cf:
    mejores_fandoms.append(i)
print(f'Fandoms en nuestra base de datos: ', mejores_fandoms)
# Out:
# Fandoms en nuestra base de datos:  ['NCTzen', 'ARMY', 'EXO-L']

# %% [markdown]
# Pero, ¿a qué grupo hace referencia cada fandom?

# %%
fandoms = todos_artistas[todos_artistas['Fanclub Name'].isin(mejores_fandoms)]
lista_def=list(fandoms['Name'])
print(f'Grupos con los fandoms más potentes: ', lista_def)
# Out:
# Grupos con los fandoms más potentes:  ['NCT', 'BTS', 'EXO']

# %% [markdown]
# Vamos a ir haciendo nuestra lista final añadiendo a los grupos que acabamos de obtener.

# %%
lista_def1=list(df_grupos_nuevos['Grupo'])
for i in lista_def1:
  if i not in lista_def:
    lista_def.append(i)
print(f'Lista provisional: ',lista_def, len(lista_def))
# Out:
# Lista provisional:  ['NCT', 'BTS', 'EXO', 'TWICE', 'BLACKPINK', 'TXT'] 6

# %% [markdown]
# A continuación, vamos a hacer un análisis de las mejores discográficas, ya que, depende de la discográfica, un grupo se puede hacer más famoso y puede ir a más eventos o festivales, por lo que se hace más conocido y más seguido.

# %% [markdown]
# Enlace mejores sellos discográficos de k-pop: https://www.eleconomista.es/mercados-cotizaciones/noticias/12306353/06/23/la-fiebre-del-kpop-se-aduena-de-los-mercados-con-subidas-del-100-y-conquista-a-los-analistas.html

# %%
mejores_sellos_discográficos=['Hybe','SM','YG','JYP']

# %% [markdown]
# Comprobamos de todos los grupos anteriores cuantos están asociados a los sellos anteriores.

# %%
sellos = todos_artistas[todos_artistas['Company'].isin(mejores_sellos_discográficos)]
sellos
# Out:
#              Name Korean Name      Debut Company  Members Fanclub Name Gender  \
# 89           ITZY          있지 2019-02-12     JYP        5        Mitzy   Girl
# 91            NCT         엔시티 2016-04-09      SM       18       NCTzen    Boy
# 59           iKON         아이콘 2015-09-15      YG        6       iKONIC    Boy
# 145        WINNER          위너 2014-08-12      YG        4          Ace    Boy
# 48           GOT7         갓세븐 2014-01-16     JYP        7       I GOT7    Boy
# 43            EXO          엑소 2012-04-08      SM        9        EXO-L    Boy
# 108        SHINee         샤이니 2008-05-22      SM        4       Shawol    Boy
# 5             2PM         투피엠 2008-07-04     JYP        6      Hottest    Boy
# 21        BIGBANG          빅뱅 2006-08-19      YG        4          VIP    Boy
# 116  Super Junior       슈퍼주니어 2005-11-06      SM       11          ELF    Boy
#
#      Year
# 89   2019
# 91   2016
# 59   2015
# 145  2014
# 48   2014
# 43   2012
# 108  2008
# 5    2008
# 21   2006
# 116  2005

# %% [markdown]
# Vemos que entre estos grupos aparecen algunos que ya teníamos, por lo que vamos a eliminarlos para que no nos molesten.

# %%
sellos = sellos.drop([91,43])
sellos
# Out:
#              Name Korean Name      Debut Company  Members Fanclub Name Gender  \
# 89           ITZY          있지 2019-02-12     JYP        5        Mitzy   Girl
# 59           iKON         아이콘 2015-09-15      YG        6       iKONIC    Boy
# 145        WINNER          위너 2014-08-12      YG        4          Ace    Boy
# 48           GOT7         갓세븐 2014-01-16     JYP        7       I GOT7    Boy
# 108        SHINee         샤이니 2008-05-22      SM        4       Shawol    Boy
# 5             2PM         투피엠 2008-07-04     JYP        6      Hottest    Boy
# 21        BIGBANG          빅뱅 2006-08-19      YG        4          VIP    Boy
# 116  Super Junior       슈퍼주니어 2005-11-06      SM       11          ELF    Boy
#
#      Year
# 89   2019
# 59   2015
# 145  2014
# 48   2014
# 108  2008
# 5    2008
# 21   2006
# 116  2005

# %% [markdown]
# Como hemos dicho antes, el año es muy importante, ya que, aunque pueden haber grupos con un debut anterior y que sigan siendo de los más seguidos, la realidad es que los grupos con unos 5 años de antigüedad suelen ser los más consolidados, ya que han pasado por el principio, se han ganado su fama y ahora tienen a sus seguidores muy claros. Por contra, un grupo que lleva 20 años encima de los escenarios suele ser menos seguido, ya que los fans de estos grupos han cambiado de época en su vida y puede ser que escuchen sus canciones en casa pero que no vayan a los conciertos.
#
# Por este motivo, vamos a coger los 4 primeros grupos, ordenados por año de debut, para completar la lista de los 10 grupos para nuestro festival.

# %%
sellos=sellos[:4]
sellos
# Out:
#        Name Korean Name      Debut Company  Members Fanclub Name Gender  Year
# 89     ITZY          있지 2019-02-12     JYP        5        Mitzy   Girl  2019
# 59     iKON         아이콘 2015-09-15      YG        6       iKONIC    Boy  2015
# 145  WINNER          위너 2014-08-12      YG        4          Ace    Boy  2014
# 48     GOT7         갓세븐 2014-01-16     JYP        7       I GOT7    Boy  2014

# %% [markdown]
# Obtenemos ahora los nombres de estos grupos.

# %%
sellos_names=list(sellos['Name'])
for i in sellos_names:
  lista_def.append(i)

# %%
lista_def
# Out:
# ['NCT',
#  'BTS',
#  'EXO',
#  'TWICE',
#  'BLACKPINK',
#  'TXT',
#  'ITZY',
#  'iKON',
#  'WINNER',
#  'GOT7']

# %% [markdown]
# Para terminar realizamos el dataframe final con todos los datos que queremos.

# %%
df_final1=df2[df2['Name'].isin(lista_def)]
df_final2=df3[df3['Name'].isin(lista_def)]
df_final=pd.concat([df_final1,df_final2])
df_final=df_final.reset_index()
df_final=df_final.drop(['index','Active'],axis=1)
df_final['Gender'] = ['Boy','Boy','Boy','Boy','Boy','Boy','Boy','Girl','Girl','Girl']
df_final
# Out:
#         Name Korean Name      Debut  Company  Members Fanclub Name Gender
# 0        BTS       방탄소년단 2013-06-13  Big Hit        7         ARMY    Boy
# 1        EXO          엑소 2012-04-08       SM        9        EXO-L    Boy
# 2       GOT7         갓세븐 2014-01-16      JYP        7       I GOT7    Boy
# 3       iKON         아이콘 2015-09-15       YG        6       iKONIC    Boy
# 4        NCT         엔시티 2016-04-09       SM       18       NCTzen    Boy
# 5        TXT   투모로우바이투게더 2019-03-04  Big Hit        5          NaN    Boy
# 6     WINNER          위너 2014-08-12       YG        4          Ace    Boy
# 7  BLACKPINK        블랙핑크 2016-08-08       YG        4          NaN   Girl
# 8       ITZY          있지 2019-02-12      JYP        5        Mitzy   Girl
# 9      TWICE        트와이스 2015-10-20      JYP        9         Once   Girl

# %% [markdown]
# Aunque este dataframe sale que TXT y BLACKPINK no tiene club de fans esto no es la realidad, por lo que vamos a cambiar esto para tener la base de datos bien.

# %%
df_final.iloc[5,5]='MOA'
df_final.iloc[7,5]='BLINK'
df_final
# Out:
#         Name Korean Name      Debut  Company  Members Fanclub Name Gender
# 0        BTS       방탄소년단 2013-06-13  Big Hit        7         ARMY    Boy
# 1        EXO          엑소 2012-04-08       SM        9        EXO-L    Boy
# 2       GOT7         갓세븐 2014-01-16      JYP        7       I GOT7    Boy
# 3       iKON         아이콘 2015-09-15       YG        6       iKONIC    Boy
# 4        NCT         엔시티 2016-04-09       SM       18       NCTzen    Boy
# 5        TXT   투모로우바이투게더 2019-03-04  Big Hit        5          MOA    Boy
# 6     WINNER          위너 2014-08-12       YG        4          Ace    Boy
# 7  BLACKPINK        블랙핑크 2016-08-08       YG        4        BLINK   Girl
# 8       ITZY          있지 2019-02-12      JYP        5        Mitzy   Girl
# 9      TWICE        트와이스 2015-10-20      JYP        9         Once   Girl

# %%
df_final.to_csv('df_final.csv', index=False)
